# %%
# %%capture
# !pip install simple-icd-10 
# !pip install simple-icd-10-cm
# !pip install datasets sentence-transformers setfit

# %%
import json 
import pandas as pd
import simple_icd_10_cm as icd
from datasets import load_dataset,Dataset
from sentence_transformers.losses import CosineSimilarityLoss
from setfit import SetFitModel, SetFitTrainer
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
df = pd.DataFrame(json.load(open("/content/icd_json.json","r"))) 
df["text"] = df.text.apply(lambda i: i.get("codeDescription"))
df["icd-l3"] = df.icd10Code.str[0:3]
df["icd-l3-description"] = df["icd-l3"].apply(icd.get_description)
df["icd_group"] = df["icd-l3"].apply(icd.get_parent)
df["icd_group_description"] = df["icd_group"].apply(icd.get_description)
df["icd_general_group"] = df["icd_group"].apply(icd.get_parent)
df["icd_general_group_description"] = df["icd_general_group"].apply(icd.get_description)
#label_encoder = LabelEncoder()
#df["labels"] = label_encoder.fit_transform(df["icd_group_description"])
df["labels"] = df["icd-l3-description"]

# %%
sdf = df.groupby("labels").sample(15,replace=True)

# %%
dataset = Dataset.from_pandas(sdf)

# %%
dataset = dataset.class_encode_column("labels")
# Out:
# Casting to class labels:   0%|          | 0/26 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
dataset = dataset.train_test_split(test_size=0.2)

# %%
# Simulate the few-shot regime by sampling 8 examples per class
#num_classes = len(label_encoder.classes_)
#train_dataset = dataset["train"].shuffle(seed=5896)
#eval_dataset = dataset["test"]

target_feature = dataset["train"].features["labels"]
num_classes = target_feature.num_classes
label_names = target_feature.names

id2label = {str(i): label for i, label in enumerate(label_names)}
label2id = {v: k for k, v in id2label.items()}

# %%
train_dataset = dataset["train"].shuffle(7854)
eval_dataset = dataset["test"]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['icd10Code', 'text', 'icd-l3', 'icd-l3-description', 'icd_group', 'icd_group_description', 'icd_general_group', 'icd_general_group_description', 'labels', '__index_level_0__'],
#     num_rows: 20232
# })

# %%
# Load a SetFit model from Hub
model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-mpnet-base-v2",num_labels=num_classes,id2label=id2label,label2id=label2id)

# Create trainer
trainer = SetFitTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    loss_class=CosineSimilarityLoss,
    metric="accuracy",
    batch_size=450,
    num_iterations=15, # The number of text pairs to generate for contrastive learning
    num_epochs=5, # The number of epochs to use for constrastive learning
    column_mapping={"text": "text", "labels": "label"} # Map dataset columns to text/label expected by trainer
)

# Train and evaluate
trainer.train()
metrics = trainer.evaluate()
# Out:
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Applying column mapping to training dataset
# ***** Running training *****
#   Num examples = 606960
#   Num epochs = 5
#   Total optimization steps = 1349
#   Total train batch size = 450
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1349 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1349 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1349 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1349 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1349 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Applying column mapping to evaluation dataset
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
# ***** Running evaluation *****

# %%
trainer.model.save_pretrained("/content/drive/MyDrive/other/icd_setfit",)

# %%
joblib.dump([id2label,label2id],"/content/drive/MyDrive/other/icd_setfit/label_encoder.joblib")
# Out:
# ['/content/drive/MyDrive/other/icd_setfit/label_encoder.joblib']

# %%
# %env TOKEN_HF=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
# Out:
# env: TOKEN_HF=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

# %%
import os
trainer.push_to_hub("setfit-ST-ICD10-L3",use_auth_token=os.getenv("TOKEN_HF"))
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:42: FutureWarning: Deprecated positional argument(s) used in 'push_to_hub': pass repo_path_or_name='setfit-ST-ICD10-L3', repo_url=None, commit_message='Add SetFit model', organization=None, private=None, api_endpoint=None, use_auth_token='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', git_user=None, git_email=None, config=None, skip_lfs_files=False as keyword args. From version 0.12 passing these as positional arguments will result in an error,
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'push_to_hub': repo_path_or_name, use_auth_token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
# Cloning https://huggingface.co/rjac/setfit-ST-ICD10-L3 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/rjac/setfit-ST-ICD10-L3 into local empty directory.
# Upload file pytorch_model.bin:   0%|          | 3.34k/418M [00:00<?, ?B/s]
# Upload file model_head.pkl:   0%|          | 3.34k/9.91M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/rjac/setfit-ST-ICD10-L3
#    637a5a8..76e1c33  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/rjac/setfit-ST-ICD10-L3
#    637a5a8..76e1c33  main -> main
# 'https://huggingface.co/rjac/setfit-ST-ICD10-L3/commit/76e1c33f9eeca324f7d36e09901d214d8b78bc21'

# %%
model_final = SetFitModel.from_pretrained("rjac/setfit-ST-ICD10-L3")
# Out:
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.70k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.4M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.4M [00:00<?, ?B/s]

# %%
model_final(["Diabetis"])
# Out:
# array([661])

# %%
labeler = joblib.load("/content/drive/MyDrive/other/icd_setfit/label_encoder.joblib")

# %%
labeler[0]
# Out:
# {'0': 'Abdominal and pelvic pain',
#  '1': 'Abnormal and inconclusive findings on diagnostic imaging of breast',
#  '2': 'Abnormal blood-pressure reading, without diagnosis',
#  '3': 'Abnormal findings in cerebrospinal fluid',
#  '4': 'Abnormal findings in other body fluids and substances',
#  '5': 'Abnormal findings in specimens from digestive organs and abdominal cavity',
#  '6': 'Abnormal findings in specimens from female genital organs',
#  '7': 'Abnormal findings in specimens from male genital organs',
#  '8': 'Abnormal findings in specimens from other organs, systems and tissues',
#  '9': 'Abnormal findings in specimens from respiratory organs and thorax',
#  '10': 'Abnormal findings on antenatal screening of mother',
#  '11': 'Abnormal findings on diagnostic imaging of central nervous system',
#  '12': 'Abnormal findings on diagnostic imaging of lung',
#  '13': 'Abnormal findings on diagnostic imaging of other body structures',
#  '14': 'Abnormal involuntary movements',
#  '15': 'Abnormal results of function studies',
#  '16': 'Abnormal serum enzyme levels',
#  '17': 'Abnormal tumor markers',
#  '18': 'Abnormalities of breathing',
#  '19': 'Abnormalities of forces of labor',
#  '20': 'Abnormalities of gait and mobility',
#  '21': 'Abnormalities of heart beat',
#  '22': 'Abnormality of red blood cells',
#  '23': 'Abscess of anal and rectal regions',
#  '24': 'Abscess of lung and mediastinum',
#  '25': 'Absent, scanty and rare menstruation',
#  '26': 'Abuse of non-psychoactive substances',
#  '27': 'Accident to nonpowered aircraft causing injury to occupant',
#  '28': 'Accident to powered aircraft causing injury to occupant',
#  '29': 'Accidental discharge and malfunction from other and unspecified firearms and guns',
#  '30': 'Accidental drowning and submersion while in bath-tub',
#  '31': 'Accidental drowning and submersion while in natural water',
#  '32': 'Accidental drowning and submersion while in swimming-pool',
#  '33': 'Accidental handgun discharge and malfunction',
#  '34': 'Accidental hit, strike, kick, twist, bite or scratch by another person',
#  '35': 'Accidental rifle, shotgun and larger firearm discharge and malfunction',
#  '36': 'Accidental striking against or bumped into by another person',
#  '37': 'Acne',
#  '38': 'Acquired absence of limb',
#  '39': 'Acquired absence of organs, not elsewhere classified',
#  '40': 'Acquired deformities of fingers and toes',
#  '41': 'Acquired hemolytic anemia',
#  '42': 'Acquired pure red cell aplasia [erythroblastopenia]',
#  '43': 'Actinomycosis',
#  '44': 'Activity codes',
#  '45': 'Acute and subacute endocarditis',
#  '46': 'Acute appendicitis',
#  '47': 'Acute bronchiolitis',
#  '48': 'Acute bronchitis',
#  '49': 'Acute hepatitis A',
#  '50': 'Acute hepatitis B',
#  '51': 'Acute kidney failure',
#  '52': 'Acute laryngitis and tracheitis',
#  '53': 'Acute lymphadenitis',
#  '54': 'Acute myocardial infarction',
#  '55': 'Acute myocarditis',
#  '56': 'Acute nephritic syndrome',
#  '57': 'Acute obstructive laryngitis [croup] and epiglottitis',
#  '58': 'Acute pancreatitis',
#  '59': 'Acute pericarditis',
#  '60': 'Acute pharyngitis',
#  '61': 'Acute poliomyelitis',
#  '62': 'Acute sinusitis',
#  '63': 'Acute tonsillitis',
#  '64': 'Acute upper respiratory infections of multiple and unspecified sites',
#  '65': 'Adrenogenital disorders',
#  '66': 'Adult and child abuse, neglect and other maltreatment, confirmed',
#  '67': 'Adult and child abuse, neglect and other maltreatment, suspected',
#  '68': 'Adult osteomalacia',
#  '69': 'Adverse effects, not elsewhere classified',
#  '70': 'African trypanosomiasis',
#  '71': 'Age-related cataract',
#  '72': 'Airway disease due to specific organic dust',
#  '73': 'Alcohol related disorders',
#  '74': 'Alcoholic liver disease',
#  '75': 'Allergic contact dermatitis',
#  '76': 'Allergy status to drugs, medicaments and biological substances',
#  '77': 'Alopecia areata',
#  '78': "Alzheimer's disease",
#  '79': 'Amebiasis',
#  '80': 'Amyloidosis',
#  '81': 'Androgenic alopecia',
#  '82': 'Anemia due to enzyme disorders',
#  '83': 'Anemia in chronic diseases classified elsewhere',
#  '84': 'Anencephaly and similar malformations',
#  '85': 'Anesthesiology devices associated with adverse incidents',
#  '86': 'Angina pectoris',
#  '87': 'Animal-rider or occupant of animal-drawn vehicle injured in transport accident',
#  '88': 'Ankylosing spondylitis',
#  '89': 'Anogenital herpesviral [herpes simplex] infections',
#  '90': 'Anophthalmos, microphthalmos and macrophthalmos',
#  '91': 'Antepartum hemorrhage, not elsewhere classified',
#  '92': 'Anthrax',
#  '93': 'Aortic aneurysm and dissection',
#  '94': 'Aphagia and dysphagia',
#  '95': 'Apocrine sweat disorders',
#  '96': 'Arenaviral hemorrhagic fever',
#  '97': 'Arterial embolism and thrombosis',
#  '98': 'Arthropathies in other diseases classified elsewhere',
#  '99': 'Artificial opening status',
#  '100': 'Ascariasis',
#  '101': 'Ascites',
#  '102': 'Aspergillosis',
#  '103': 'Asphyxiation',
#  '104': 'Assault by blunt object',
#  '105': 'Assault by bodily force',
#  '106': 'Assault by crashing of motor vehicle',
#  '107': 'Assault by drowning and submersion',
#  '108': 'Assault by explosive material',
#  '109': 'Assault by handgun discharge',
#  '110': 'Assault by other and unspecified firearm and gun discharge',
#  '111': 'Assault by other specified means',
#  '112': 'Assault by pushing from high place',
#  '113': 'Assault by pushing or placing victim in front of moving object',
#  '114': 'Assault by rifle, shotgun and larger firearm discharge',
#  '115': 'Assault by sharp object',
#  '116': 'Assault by smoke, fire and flames',
#  '117': 'Assault by steam, hot vapors and hot objects',
#  '118': 'Asthma',
#  '119': 'Atheroembolism',
#  '120': 'Atherosclerosis',
#  '121': 'Atopic dermatitis',
#  '122': 'Atrial fibrillation and flutter',
#  '123': 'Atrioventricular and left bundle-branch block',
#  '124': 'Atrophic disorders of skin',
#  '125': 'Attention-deficit hyperactivity disorders',
#  '126': 'Atypical virus infections of central nervous system',
#  '127': 'Autoinflammatory syndromes',
#  '128': 'Avalanche, landslide and other earth movements',
#  '129': 'Avulsion and traumatic amputation of part of head',
#  '130': 'Bacterial infection of unspecified site',
#  '131': 'Bacterial meningitis, not elsewhere classified',
#  '132': 'Bacterial pneumonia, not elsewhere classified',
#  '133': 'Bacterial sepsis of newborn',
#  '134': 'Balanced rearrangements and structural markers, not elsewhere classified',
#  '135': 'Bartonellosis',
#  '136': 'Benign lipomatous neoplasm',
#  '137': 'Benign mammary dysplasia',
#  '138': 'Benign neoplasm of bone and articular cartilage',
#  '139': 'Benign neoplasm of brain and other parts of central nervous system',
#  '140': 'Benign neoplasm of breast',
#  '141': 'Benign neoplasm of colon, rectum, anus and anal canal',
#  '142': 'Benign neoplasm of eye and adnexa',
#  '143': 'Benign neoplasm of major salivary glands',
#  '144': 'Benign neoplasm of male genital organs',
#  '145': 'Benign neoplasm of meninges',
#  '146': 'Benign neoplasm of mesothelial tissue',
#  '147': 'Benign neoplasm of middle ear and respiratory system',
#  '148': 'Benign neoplasm of mouth and pharynx',
#  '149': 'Benign neoplasm of other and ill-defined parts of digestive system',
#  '150': 'Benign neoplasm of other and unspecified endocrine glands',
#  '151': 'Benign neoplasm of other and unspecified female genital organs',
#  '152': 'Benign neoplasm of other and unspecified intrathoracic organs',
#  '153': 'Benign neoplasm of other and unspecified sites',
#  '154': 'Benign neoplasm of ovary',
#  '155': 'Benign neoplasm of soft tissue of retroperitoneum and peritoneum',
#  '156': 'Benign neoplasm of urinary organs',
#  '157': 'Benign neuroendocrine tumors',
#  '158': 'Benign prostatic hyperplasia',
#  '159': 'Biomechanical lesions, not elsewhere classified',
#  '160': 'Bipolar disorder',
#  '161': 'Birth injury to peripheral nervous system',
#  '162': 'Birth injury to scalp',
#  '163': 'Birth injury to skeleton',
#  '164': 'Bitten or stung by nonvenomous insect and other nonvenomous arthropods',
#  '165': 'Blastomycosis',
#  '166': 'Blindness and low vision',
#  '167': 'Blood type',
#  '168': 'Body mass index [BMI]',
#  '169': 'Bronchiectasis',
#  '170': 'Brucellosis',
#  '171': 'Burn and corrosion confined to eye and adnexa',
#  '172': 'Burn and corrosion of ankle and foot',
#  '173': 'Burn and corrosion of head, face, and neck',
#  '174': 'Burn and corrosion of lower limb, except ankle and foot',
#  '175': 'Burn and corrosion of other internal organs',
#  '176': 'Burn and corrosion of respiratory tract',
#  '177': 'Burn and corrosion of shoulder and upper limb, except wrist and hand',
#  '178': 'Burn and corrosion of trunk',
#  '179': 'Burn and corrosion of wrist and hand',
#  '180': 'Burn and corrosion, body region unspecified',
#  '181': 'Burns classified according to extent of body surface involved',
#  '182': 'Bus occupant injured in collision with car, pick-up truck or van',
#  '183': 'Bus occupant injured in collision with fixed or stationary object',
#  '184': 'Bus occupant injured in collision with heavy transport vehicle or bus',
#  '185': 'Bus occupant injured in collision with other nonmotor vehicle',
#  '186': 'Bus occupant injured in collision with pedal cycle',
#  '187': 'Bus occupant injured in collision with pedestrian or animal',
#  '188': 'Bus occupant injured in collision with railway train or railway vehicle',
#  '189': 'Bus occupant injured in collision with two- or three-wheeled motor vehicle',
#  '190': 'Bus occupant injured in noncollision transport accident',
#  '191': 'Bus occupant injured in other and unspecified transport accidents',
#  '192': 'Calcification and ossification of muscle',
#  '193': 'Calculus of kidney and ureter',
#  '194': 'Calculus of lower urinary tract',
#  '195': 'Candidiasis',
#  '196': 'Cannabis related disorders',
#  '197': 'Car occupant injured in collision with car, pick-up truck or van',
#  '198': 'Car occupant injured in collision with fixed or stationary object',
#  '199': 'Car occupant injured in collision with heavy transport vehicle or bus',
#  '200': 'Car occupant injured in collision with other nonmotor vehicle',
#  '201': 'Car occupant injured in collision with pedal cycle',
#  '202': 'Car occupant injured in collision with pedestrian or animal',
#  '203': 'Car occupant injured in collision with railway train or railway vehicle',
#  '204': 'Car occupant injured in collision with two- or three-wheeled motor vehicle',
#  '205': 'Car occupant injured in noncollision transport accident',
#  '206': 'Car occupant injured in other and unspecified transport accidents',
#  '207': 'Carcinoma in situ of breast',
#  '208': 'Carcinoma in situ of cervix uteri',
#  '209': 'Carcinoma in situ of middle ear and respiratory system',
#  '210': 'Carcinoma in situ of oral cavity, esophagus and stomach',
#  '211': 'Carcinoma in situ of other and unspecified digestive organs',
#  '212': 'Carcinoma in situ of other and unspecified genital organs',
#  '213': 'Carcinoma in situ of other and unspecified sites',
#  '214': 'Carcinoma in situ of skin',
#  '215': 'Cardiac arrest',
#  '216': 'Cardiac murmurs and other cardiac sounds',
#  '217': 'Cardiomyopathy',
#  '218': 'Cardiovascular devices associated with adverse incidents',
#  '219': 'Cardiovascular disorders originating in the perinatal period',
#  '220': 'Carrier of infectious disease',
#  '221': 'Cataclysmic storm',
#  '222': 'Caught, crushed, jammed or pinched in or between objects',
#  '223': 'Cellulitis and acute lymphangitis',
#  '224': 'Cerebral infarction',
#  '225': 'Cerebral palsy',
#  '226': 'Cerebrovascular disorders in diseases classified elsewhere',
#  '227': 'Certain current complications following ST elevation (STEMI) and non-ST elevation (NSTEMI) myocardial infarction (within the 28 day period)',
#  '228': 'Certain early complications of trauma, not elsewhere classified',
#  '229': 'Cervical disc disorders',
#  '230': "Chagas' disease",
#  '231': 'Cholecystitis',
#  '232': 'Cholelithiasis',
#  '233': 'Cholera',
#  '234': 'Cholesteatoma of middle ear',
#  '235': 'Chorioretinal inflammation',
#  '236': 'Chromomycosis and pheomycotic abscess',
#  '237': 'Chronic diseases of tonsils and adenoids',
#  '238': 'Chronic gout',
#  '239': 'Chronic hepatitis, not elsewhere classified',
#  '240': 'Chronic ischemic heart disease',
#  '241': 'Chronic kidney disease (CKD)',
#  '242': 'Chronic laryngitis and laryngotracheitis',
#  '243': 'Chronic nephritic syndrome',
#  '244': 'Chronic respiratory disease originating in the perinatal period',
#  '245': 'Chronic rhinitis, nasopharyngitis and pharyngitis',
#  '246': 'Chronic sinusitis',
#  '247': 'Chronic tubulo-interstitial nephritis',
#  '248': 'Chronic viral hepatitis',
#  '249': 'Cicatricial alopecia [scarring hair loss]',
#  '250': 'Cleft lip',
#  '251': 'Cleft palate',
#  '252': 'Cleft palate with cleft lip',
#  '253': 'Cocaine related disorders',
#  '254': 'Coccidioidomycosis',
#  '255': 'Combined immunodeficiencies',
#  '256': 'Common variable immunodeficiency',
#  '257': 'Complications and ill-defined descriptions of heart disease',
#  '258': 'Complications associated with artificial fertilization',
#  '259': 'Complications following (induced) termination of pregnancy',
#  '260': 'Complications following ectopic and molar pregnancy',
#  '261': 'Complications following infusion, transfusion and therapeutic injection',
#  '262': 'Complications of anesthesia during labor and delivery',
#  '263': 'Complications of anesthesia during pregnancy',
#  '264': 'Complications of anesthesia during the puerperium',
#  '265': 'Complications of artificial openings of the digestive system',
#  '266': 'Complications of bariatric procedures',
#  '267': 'Complications of cardiac and vascular prosthetic devices, implants and grafts',
#  '268': 'Complications of genitourinary prosthetic devices, implants and grafts',
#  '269': 'Complications of internal orthopedic prosthetic devices, implants and grafts',
#  '270': 'Complications of other internal prosthetic devices, implants and grafts',
#  '271': 'Complications of procedures, not elsewhere classified',
#  '272': 'Complications of the puerperium, not elsewhere classified',
#  '273': 'Complications of transplanted organs and tissue',
#  '274': 'Complications peculiar to reattachment and amputation',
#  '275': 'Complications specific to multiple gestation',
#  '276': 'Conduct disorders',
#  '277': 'Conductive and sensorineural hearing loss',
#  '278': 'Congenital absence, atresia and stenosis of large intestine',
#  '279': 'Congenital absence, atresia and stenosis of small intestine',
#  '280': 'Congenital deformities of feet',
#  '281': 'Congenital deformities of hip',
#  '282': 'Congenital hydrocephalus',
#  '283': 'Congenital ichthyosis',
#  '284': 'Congenital iodine-deficiency syndrome',
#  '285': 'Congenital lens malformations',
#  '286': 'Congenital malformation syndromes due to known exogenous causes, not elsewhere classified',
#  '287': 'Congenital malformations of anterior segment of eye',
#  '288': 'Congenital malformations of aortic and mitral valves',
#  '289': 'Congenital malformations of breast',
#  '290': 'Congenital malformations of cardiac chambers and connections',
#  '291': 'Congenital malformations of cardiac septa',
#  '292': 'Congenital malformations of ear causing impairment of hearing',
#  '293': 'Congenital malformations of esophagus',
#  '294': 'Congenital malformations of eyelid, lacrimal apparatus and orbit',
#  '295': 'Congenital malformations of gallbladder, bile ducts and liver',
#  '296': 'Congenital malformations of great arteries',
#  '297': 'Congenital malformations of great veins',
#  '298': 'Congenital malformations of larynx',
#  '299': 'Congenital malformations of lung',
#  '300': 'Congenital malformations of musculoskeletal system, not elsewhere classified',
#  '301': 'Congenital malformations of nose',
#  '302': 'Congenital malformations of ovaries, fallopian tubes and broad ligaments',
#  '303': 'Congenital malformations of posterior segment of eye',
#  '304': 'Congenital malformations of pulmonary and tricuspid valves',
#  '305': 'Congenital malformations of spine and bony thorax',
#  '306': 'Congenital malformations of trachea and bronchus',
#  '307': 'Congenital malformations of uterus and cervix',
#  '308': 'Congenital musculoskeletal deformities of head, face, spine and chest',
#  '309': 'Congenital obstructive defects of renal pelvis and congenital malformations of ureter',
#  '310': 'Congenital pneumonia',
#  '311': 'Congenital syphilis',
#  '312': 'Congenital viral diseases',
#  '313': 'Conjunctivitis',
#  '314': 'Contact with agricultural machinery',
#  '315': 'Contact with and (suspected) exposure to communicable diseases',
#  '316': 'Contact with birds (domestic) (wild)',
#  '317': 'Contact with blunt object, undetermined intent',
#  '318': 'Contact with crocodile or alligator',
#  '319': 'Contact with dog',
#  '320': 'Contact with explosive material, undetermined intent',
#  '321': 'Contact with hot air and other hot gases',
#  '322': 'Contact with hot drinks, food, fats and cooking oils',
#  '323': 'Contact with hot engines, machinery and tools',
#  '324': 'Contact with hot heating appliances, radiators and pipes',
#  '325': 'Contact with hot household appliances',
#  '326': 'Contact with hot tap-water',
#  '327': 'Contact with hypodermic needle',
#  '328': 'Contact with lifting and transmission devices, not elsewhere classified',
#  '329': 'Contact with nonpowered hand tool',
#  '330': 'Contact with nonvenomous amphibians',
#  '331': 'Contact with nonvenomous marine animal',
#  '332': 'Contact with nonvenomous plant thorns and spines and sharp leaves',
#  '333': 'Contact with other and unspecified machinery',
#  '334': 'Contact with other heat and hot substances',
#  '335': 'Contact with other hot fluids',
#  '336': 'Contact with other hot metals',
#  '337': 'Contact with other mammals',
#  '338': 'Contact with other nonvenomous reptiles',
#  '339': 'Contact with other powered hand tools and household machinery',
#  '340': 'Contact with other sharp objects',
#  '341': 'Contact with powered lawn mower',
#  '342': 'Contact with rodent',
#  '343': 'Contact with sharp glass',
#  '344': 'Contact with sharp object, undetermined intent',
#  '345': 'Contact with steam and other hot vapors',
#  '346': 'Contact with steam, hot vapors and hot objects, undetermined intent',
#  '347': 'Contaminated medical or biological substances',
#  '348': 'Convulsions, not elsewhere classified',
#  '349': 'Corneal scars and opacities',
#  '350': 'Corrosions classified according to extent of body surface involved',
#  '351': 'Counseling related to sexual attitude, behavior and orientation',
#  '352': 'Crashing of motor vehicle, undetermined intent',
#  '353': "Crohn's disease [regional enteritis]",
#  '354': 'Crushed, pushed or stepped on by crowd or human stampede',
#  '355': 'Crushing injury and traumatic amputation of abdomen, lower back, pelvis and external genitals',
#  '356': 'Crushing injury of ankle and foot',
#  '357': 'Crushing injury of elbow and forearm',
#  '358': 'Crushing injury of head',
#  '359': 'Crushing injury of hip and thigh',
#  '360': 'Crushing injury of lower leg',
#  '361': 'Crushing injury of neck',
#  '362': 'Crushing injury of shoulder and upper arm',
#  '363': 'Crushing injury of thorax, and traumatic amputation of part of thorax',
#  '364': 'Crushing injury of wrist, hand and fingers',
#  '365': 'Cryptococcosis',
#  '366': "Cushing's syndrome",
#  '367': 'Cutaneous abscess, furuncle and carbuncle',
#  '368': 'Cystic fibrosis',
#  '369': 'Cystic kidney disease',
#  '370': 'Cysticercosis',
#  '371': 'Cystitis',
#  '372': 'Cysts of oral region, not elsewhere classified',
#  '373': 'Cytomegaloviral disease',
#  '374': 'Deficiency of other B group vitamins',
#  '375': 'Deficiency of other nutrient elements',
#  '376': 'Deformity and disproportion of reconstructed breast',
#  '377': 'Dementia in other diseases classified elsewhere',
#  '378': 'Dental caries',
#  '379': 'Dentofacial anomalies [including malocclusion]',
#  '380': 'Dependence on enabling machines and devices, not elsewhere classified',
#  '381': 'Dermatitis due to substances taken internally',
#  '382': 'Dermatophytosis',
#  '383': 'Dermatopolymyositis',
#  '384': 'Diabetes mellitus due to underlying condition',
#  '385': 'Diabetes mellitus in pregnancy, childbirth, and the puerperium',
#  '386': 'Diaphragmatic hernia',
#  '387': 'Diphtheria',
#  '388': 'Diphyllobothriasis and sparganosis',
#  '389': 'Direct infections of joint in infectious and parasitic diseases classified elsewhere',
#  '390': 'Discharge of firework',
#  '391': "Diseases of Bartholin's gland",
#  '392': 'Diseases of capillaries',
#  '393': 'Diseases of pulp and periapical tissues',
#  '394': 'Diseases of salivary glands',
#  '395': 'Diseases of spleen',
#  '396': 'Diseases of thymus',
#  '397': 'Diseases of tongue',
#  '398': 'Diseases of vocal cords and larynx, not elsewhere classified',
#  '399': 'Dislocation and sprain of joint and ligaments of hip',
#  '400': 'Dislocation and sprain of joints and ligaments at ankle, foot and toe level',
#  '401': 'Dislocation and sprain of joints and ligaments at neck level',
#  '402': 'Dislocation and sprain of joints and ligaments at wrist and hand level',
#  '403': 'Dislocation and sprain of joints and ligaments of elbow',
#  '404': 'Dislocation and sprain of joints and ligaments of head',
#  '405': 'Dislocation and sprain of joints and ligaments of knee',
#  '406': 'Dislocation and sprain of joints and ligaments of lumbar spine and pelvis',
#  '407': 'Dislocation and sprain of joints and ligaments of shoulder girdle',
#  '408': 'Dislocation and sprain of joints and ligaments of thorax',
#  '409': 'Disorder of continuity of bone',
#  '410': 'Disorder of patella',
#  '411': 'Disorders of aromatic amino-acid metabolism',
#  '412': 'Disorders of arteries, arterioles and capillaries in diseases classified elsewhere',
#  '413': 'Disorders of autonomic nervous system',
#  '414': 'Disorders of branched-chain amino-acid metabolism and fatty-acid metabolism',
#  '415': 'Disorders of external ear in diseases classified elsewhere',
#  '416': 'Disorders of globe',
#  '417': 'Disorders of glycoprotein metabolism',
#  '418': 'Disorders of glycosaminoglycan metabolism',
#  '419': 'Disorders of lacrimal system',
#  '420': 'Disorders of lipoprotein metabolism and other lipidemias',
#  '421': 'Disorders of mineral metabolism',
#  '422': 'Disorders of muscle in diseases classified elsewhere',
#  '423': 'Disorders of muscle tone of newborn',
#  '424': 'Disorders of myoneural junction and muscle in diseases classified elsewhere',
#  '425': 'Disorders of newborn related to long gestation and high birth weight',
#  '426': 'Disorders of newborn related to short gestation and low birth weight, not elsewhere classified',
#  '427': 'Disorders of newborn related to slow fetal growth and fetal malnutrition',
#  '428': 'Disorders of orbit',
#  '429': 'Disorders of other cranial nerves',
#  '430': 'Disorders of porphyrin and bilirubin metabolism',
#  '431': 'Disorders of prepuce',
#  '432': 'Disorders of puberty, not elsewhere classified',
#  '433': 'Disorders of purine and pyrimidine metabolism',
#  '434': 'Disorders of refraction and accommodation',
#  '435': 'Disorders of retroperitoneum',
#  '436': 'Disorders of sclera',
#  '437': 'Disorders of social functioning with onset specific to childhood and adolescence',
#  '438': 'Disorders of sphingolipid metabolism and other lipid storage disorders',
#  '439': 'Disorders of tooth development and eruption',
#  '440': 'Disorders of trigeminal nerve',
#  '441': 'Disorders of vestibular function',
#  '442': 'Disorders of vitreous body',
#  '443': 'Disorders resulting from impaired renal tubular function',
#  '444': 'Dissociative and conversion disorders',
#  '445': 'Disturbances of skin sensation',
#  '446': 'Disturbances of smell and taste',
#  '447': 'Diverticular disease of intestine',
#  '448': 'Donors of organs and tissues',
#  '449': 'Dorsalgia',
#  '450': 'Down syndrome',
#  '451': 'Drowning and submersion due to accident on board watercraft, without accident to watercraft',
#  '452': 'Drowning and submersion due to accident to watercraft',
#  '453': 'Drowning and submersion, undetermined intent',
#  '454': 'Drug or chemical induced diabetes mellitus',
#  '455': 'Drug- and heavy-metal-induced tubulo-interstitial and tubular conditions',
#  '456': 'Duodenal ulcer',
#  '457': 'Dyslexia and other symbolic dysfunctions, not elsewhere classified',
#  '458': 'Dysplasia of cervix uteri',
#  '459': 'Dystonia',
#  '460': 'Early syphilis',
#  '461': 'Earthquake',
#  '462': 'Eating disorders',
#  '463': 'Eccrine sweat disorders',
#  '464': 'Echinococcosis',
#  '465': 'Eclampsia',
#  '466': 'Ectopic pregnancy',
#  '467': 'Edema, not elsewhere classified',
#  '468': 'Effects of air pressure and water pressure',
#  '469': 'Effects of heat and light',
#  '470': 'Effects of other deprivation',
#  '471': 'Elevated blood glucose level',
#  '472': 'Elevated erythrocyte sedimentation rate and abnormality of plasma viscosity',
#  '473': 'Embedded and impacted teeth',
#  '474': 'Emotional disorders with onset specific to childhood',
#  '475': 'Emphysema',
#  '476': 'Encephalitis, myelitis and encephalomyelitis',
#  '477': 'Encephalitis, myelitis and encephalomyelitis in diseases classified elsewhere',
#  '478': 'Encephalocele',
#  '479': 'Encounter for adjustment and management of implanted device',
#  '480': 'Encounter for administrative examination',
#  '481': 'Encounter for antenatal screening of mother',
#  '482': 'Encounter for attention to artificial openings',
#  '483': 'Encounter for care involving renal dialysis',
#  '484': 'Encounter for contraceptive management',
#  '485': 'Encounter for examination and observation for other reasons',
#  '486': 'Encounter for fitting and adjustment of external prosthetic device',
#  '487': 'Encounter for fitting and adjustment of other devices',
#  '488': 'Encounter for general examination without complaint, suspected or reported diagnosis',
#  '489': 'Encounter for maternal postpartum care and examination',
#  '490': 'Encounter for medical observation for suspected diseases and conditions ruled out',
#  '491': 'Encounter for mental health services for victim and perpetrator of abuse',
#  '492': 'Encounter for observation and evaluation of newborn for suspected diseases and conditions ruled out',
#  '493': 'Encounter for other aftercare and medical care',
#  '494': 'Encounter for other postprocedural aftercare',
#  '495': 'Encounter for other prophylactic measures',
#  '496': 'Encounter for other special examination without complaint, suspected or reported diagnosis',
#  '497': 'Encounter for plastic and reconstructive surgery following medical procedure or healed injury',
#  '498': 'Encounter for pregnancy test and childbirth and childcare instruction',
#  '499': 'Encounter for procedures for purposes other than remedying health state',
#  '500': 'Encounter for procreative management',
#  '501': 'Encounter for prophylactic surgery',
#  '502': 'Encounter for screening for infectious and parasitic diseases',
#  '503': 'Encounter for screening for malignant neoplasms',
#  '504': 'Encounter for screening for other diseases and disorders',
#  '505': 'Encounter for supervision of normal pregnancy',
#  '506': 'Endometriosis',
#  '507': 'Enlarged lymph nodes',
#  '508': 'Enteropathic arthropathies',
#  '509': 'Enthesopathies, lower limb, excluding foot',
#  '510': 'Epidermolysis bullosa',
#  '511': 'Epilepsy and recurrent seizures',
#  '512': 'Erysipeloid',
#  '513': 'Erythema multiforme',
#  '514': 'Esophageal varices',
#  '515': 'Esophagitis',
#  '516': 'Estrogen receptor status',
#  '517': 'Eustachian salpingitis and obstruction',
#  '518': 'Evidence of alcohol involvement determined by blood alcohol level',
#  '519': 'Excessive vomiting in pregnancy',
#  '520': 'Excessive, frequent and irregular menstruation',
#  '521': 'Exfoliation due to erythematous conditions according to extent of body surface involved',
#  '522': 'Explosion and rupture of boiler',
#  '523': 'Explosion and rupture of gas cylinder',
#  '524': 'Explosion and rupture of other specified pressurized devices',
#  '525': 'Explosion and rupture of pressurized tire, pipe or hose',
#  '526': 'Explosion of other materials',
#  '527': 'Exposure to controlled fire in building or structure',
#  '528': 'Exposure to controlled fire, not in building or structure',
#  '529': 'Exposure to electric transmission lines',
#  '530': 'Exposure to excessive cold of man-made origin',
#  '531': 'Exposure to excessive heat of man-made origin',
#  '532': 'Exposure to excessive natural cold',
#  '533': 'Exposure to excessive natural heat',
#  '534': 'Exposure to high and low air pressure and changes in air pressure',
#  '535': 'Exposure to ignition of highly flammable material',
#  '536': 'Exposure to ignition or melting of nightwear',
#  '537': 'Exposure to ignition or melting of other clothing and apparel',
#  '538': 'Exposure to ionizing radiation',
#  '539': 'Exposure to man-made visible and ultraviolet light',
#  '540': 'Exposure to noise',
#  '541': 'Exposure to other animate mechanical forces',
#  '542': 'Exposure to other forces of nature',
#  '543': 'Exposure to other inanimate mechanical forces',
#  '544': 'Exposure to other man-made environmental factors',
#  '545': 'Exposure to other nonionizing radiation',
#  '546': 'Exposure to other specified electric current',
#  '547': 'Exposure to other specified factors',
#  '548': 'Exposure to other specified smoke, fire and flames',
#  '549': 'Exposure to smoke, fire and flames, undetermined intent',
#  '550': 'Exposure to sunlight',
#  '551': 'Exposure to uncontrolled fire in building or structure',
#  '552': 'Exposure to uncontrolled fire, not in building or structure',
#  '553': 'External cause status',
#  '554': 'Facial nerve disorders',
#  '555': 'Failed attempted termination of pregnancy',
#  '556': 'Failed induction of labor',
#  '557': 'Failure in dosage during surgical and medical care',
#  '558': 'Failure of sterile precautions during surgical and medical care',
#  '559': 'Fall due to ice and snow',
#  '560': 'Fall from bed',
#  '561': 'Fall from chair',
#  '562': 'Fall from cliff',
#  '563': 'Fall from non-moving wheelchair, nonmotorized scooter and motorized mobility scooter',
#  '564': 'Fall from other furniture',
#  '565': 'Fall from tree',
#  '566': 'Fall from, out of or through building or structure',
#  '567': 'Fall on and from ladder',
#  '568': 'Fall on and from playground equipment',
#  '569': 'Fall on and from scaffolding',
#  '570': 'Fall on and from stairs and steps',
#  '571': 'Fall on same level from slipping, tripping and stumbling',
#  '572': 'Fall while being carried or supported by other persons',
#  '573': 'Fall, jump or diving into water',
#  '574': 'Falling, jumping or pushed from a high place, undetermined intent',
#  '575': 'Falling, lying or running before or into moving object, undetermined intent',
#  '576': 'False labor',
#  '577': 'Family history of certain disabilities and chronic diseases (leading to disablement)',
#  '578': 'Family history of mental and behavioral disorders',
#  '579': 'Family history of other conditions',
#  '580': 'Family history of other specific disorders',
#  '581': 'Family history of primary malignant neoplasm',
#  '582': 'Fecal incontinence',
#  '583': 'Feeding problems of newborn',
#  '584': 'Female genital prolapse',
#  '585': 'Female infertility',
#  '586': 'Femoral hernia',
#  '587': 'Fever of other and unknown origin',
#  '588': 'Fibroblastic disorders',
#  '589': 'Fibrosis and cirrhosis of liver',
#  '590': 'Filariasis',
#  '591': 'Findings of drugs and other substances, not normally found in blood',
#  '592': 'Fissure and fistula of anal and rectal regions',
#  '593': 'Fistulae involving female genital tract',
#  '594': 'Flatulence and related conditions',
#  '595': 'Flood',
#  '596': 'Folate deficiency anemia',
#  '597': 'Follicular cysts of skin and subcutaneous tissue',
#  '598': 'Follicular lymphoma',
#  '599': 'Foreign body in alimentary tract',
#  '600': 'Foreign body in ear',
#  '601': 'Foreign body in genitourinary tract',
#  '602': 'Foreign body in respiratory tract',
#  '603': 'Foreign body on external eye',
#  '604': 'Foreign body or object entering through skin',
#  '605': 'Fracture at wrist and hand level',
#  '606': 'Fracture of cervical vertebra and other parts of neck',
#  '607': 'Fracture of femur',
#  '608': 'Fracture of foot and toe, except ankle',
#  '609': 'Fracture of forearm',
#  '610': 'Fracture of lower leg, including ankle',
#  '611': 'Fracture of lumbar spine and pelvis',
#  '612': 'Fracture of rib(s), sternum and thoracic spine',
#  '613': 'Fracture of shoulder and upper arm',
#  '614': 'Fracture of skull and facial bones',
#  '615': 'Frostbite with tissue necrosis',
#  '616': 'Gastric ulcer',
#  '617': 'Gastritis and duodenitis',
#  '618': 'Gastro-esophageal reflux disease',
#  '619': 'Gastroenterology and urology devices associated with adverse incidents',
#  '620': 'Gastrojejunal ulcer',
#  '621': 'Gender identity disorders',
#  '622': 'General hospital and personal-use devices associated with adverse incidents',
#  '623': 'General- and plastic-surgery devices associated with adverse incidents',
#  '624': 'Genetic carrier',
#  '625': 'Genetic susceptibility to disease',
#  '626': 'Gestational [pregnancy-induced] edema and proteinuria without hypertension',
#  '627': 'Gestational [pregnancy-induced] hypertension without significant proteinuria',
#  '628': 'Gingivitis and periodontal diseases',
#  '629': 'Glanders and melioidosis',
#  '630': 'Glaucoma',
#  '631': 'Gonococcal infection',
#  '632': 'Gout',
#  '633': 'Granulomatous disorders of skin and subcutaneous tissue',
#  '634': 'Hair color and hair shaft abnormalities',
#  '635': 'Hallucinogen related disorders',
#  '636': 'Handgun discharge, undetermined intent',
#  '637': 'Heart failure',
#  '638': 'Hemangioma and lymphangioma, any site',
#  '639': 'Hematuria',
#  '640': 'Hemiplegia and hemiparesis',
#  '641': 'Hemolytic disease of newborn',
#  '642': 'Hemorrhage from respiratory passages',
#  '643': 'Hemorrhage in early pregnancy',
#  '644': 'Hemorrhoids and perianal venous thrombosis',
#  '645': 'Hepatic failure, not elsewhere classified',
#  '646': 'Hepatomegaly and splenomegaly, not elsewhere classified',
#  '647': 'Hereditary and idiopathic neuropathy',
#  '648': 'Hereditary ataxia',
#  '649': 'Hereditary nephropathy, not elsewhere classified',
#  '650': 'Herpesviral [herpes simplex] infections',
#  '651': 'Histoplasmosis',
#  '652': 'Hodgkin lymphoma',
#  '653': 'Hookworm diseases',
#  '654': 'Hordeolum and chalazion',
#  '655': 'Hormone sensitivity malignancy status',
#  '656': 'Hydatidiform mole',
#  '657': 'Hydrocele and spermatocele',
#  '658': 'Hydrocephalus',
#  '659': 'Hydrops fetalis due to hemolytic disease',
#  '660': 'Hyperaldosteronism',
#  '661': 'Hyperfunction of pituitary gland',
#  '662': 'Hyperparathyroidism and other disorders of parathyroid gland',
#  '663': 'Hypersensitivity pneumonitis due to organic dust',
#  '664': 'Hypertensive chronic kidney disease',
#  '665': 'Hypertensive crisis',
#  '666': 'Hypertensive heart and chronic kidney disease',
#  '667': 'Hypertensive heart disease',
#  '668': 'Hypertrichosis',
#  '669': 'Hypertrophic disorders of skin',
#  '670': 'Hypofunction and other disorders of the pituitary gland',
#  '671': 'Hypoparathyroidism',
#  '672': 'Hypospadias',
#  '673': 'Hypotension',
#  '674': 'Hypothermia',
#  '675': 'Hypothermia of newborn',
#  '676': 'Immunization not carried out and underimmunization status',
#  '677': 'Immunodeficiency associated with other major defects',
#  '678': 'Immunodeficiency with predominantly antibody defects',
#  '679': 'Impetigo',
#  '680': 'Impulse disorders',
#  '681': 'Indeterminate sex and pseudohermaphroditism',
#  '682': 'Infection due to other mycobacteria',
#  '683': 'Infections of breast associated with pregnancy, the puerperium and lactation',
#  '684': 'Infections of genitourinary tract in pregnancy',
#  '685': 'Infectious mononucleosis',
#  '686': 'Inflammatory disease of uterus, except cervix',
#  '687': 'Inflammatory diseases of prostate',
#  '688': 'Inflammatory disorders of breast',
#  '689': 'Inflammatory disorders of male genital organs, not elsewhere classified',
#  '690': 'Inflammatory polyneuropathy',
#  '691': 'Influenza due to certain identified influenza viruses',
#  '692': 'Influenza due to other identified influenza virus',
#  '693': 'Influenza due to unidentified influenza virus',
#  '694': 'Inguinal hernia',
#  '695': 'Inhalant related disorders',
#  '696': 'Injury of blood vessels at abdomen, lower back and pelvis level',
#  '697': 'Injury of blood vessels at ankle and foot level',
#  '698': 'Injury of blood vessels at forearm level',
#  '699': 'Injury of blood vessels at hip and thigh level',
#  '700': 'Injury of blood vessels at lower leg level',
#  '701': 'Injury of blood vessels at neck level',
#  '702': 'Injury of blood vessels at shoulder and upper arm level',
#  '703': 'Injury of blood vessels at wrist and hand level',
#  '704': 'Injury of blood vessels of thorax',
#  '705': 'Injury of cranial nerve',
#  '706': 'Injury of eye and orbit',
#  '707': 'Injury of heart',
#  '708': 'Injury of intra-abdominal organs',
#  '709': 'Injury of lumbar and sacral spinal cord and nerves at abdomen, lower back and pelvis level',
#  '710': 'Injury of muscle and tendon at ankle and foot level',
#  '711': 'Injury of muscle, fascia and tendon at forearm level',
#  '712': 'Injury of muscle, fascia and tendon at hip and thigh level',
#  '713': 'Injury of muscle, fascia and tendon at lower leg level',
#  '714': 'Injury of muscle, fascia and tendon at neck level',
#  '715': 'Injury of muscle, fascia and tendon at shoulder and upper arm level',
#  '716': 'Injury of muscle, fascia and tendon at wrist and hand level',
#  '717': 'Injury of nerves and spinal cord at neck level',
#  '718': 'Injury of nerves and spinal cord at thorax level',
#  '719': 'Injury of nerves at ankle and foot level',
#  '720': 'Injury of nerves at forearm level',
#  '721': 'Injury of nerves at hip and thigh level',
#  '722': 'Injury of nerves at lower leg level',
#  '723': 'Injury of nerves at shoulder and upper arm level',
#  '724': 'Injury of nerves at wrist and hand level',
#  '725': 'Injury of other and unspecified intrathoracic organs',
#  '726': 'Injury of unspecified body region',
#  '727': 'Injury of urinary and pelvic organs',
#  '728': 'Intentional self-harm by blunt object',
#  '729': 'Intentional self-harm by crashing of motor vehicle',
#  '730': 'Intentional self-harm by drowning and submersion',
#  '731': 'Intentional self-harm by explosive material',
#  '732': 'Intentional self-harm by handgun discharge',
#  '733': 'Intentional self-harm by jumping from a high place',
#  '734': 'Intentional self-harm by jumping or lying in front of moving object',
#  '735': 'Intentional self-harm by other and unspecified firearm and gun discharge',
#  '736': 'Intentional self-harm by other specified means',
#  '737': 'Intentional self-harm by rifle, shotgun and larger firearm discharge',
#  '738': 'Intentional self-harm by sharp object',
#  '739': 'Intentional self-harm by smoke, fire and flames',
#  '740': 'Intentional self-harm by steam, hot vapors and hot objects',
#  '741': 'Internal derangement of knee',
#  '742': 'Interstitial emphysema and related conditions originating in the perinatal period',
#  '743': 'Intestinal malabsorption',
#  '744': 'Intracranial and intraspinal abscess and granuloma',
#  '745': 'Intracranial injury',
#  '746': 'Intracranial laceration and hemorrhage due to birth injury',
#  '747': 'Intracranial nontraumatic hemorrhage of newborn',
#  '748': 'Intraoperative and postprocedural complications and disorders of circulatory system, not elsewhere classified',
#  '749': 'Intraoperative and postprocedural complications and disorders of digestive system, not elsewhere classified',
#  '750': 'Intraoperative and postprocedural complications and disorders of ear and mastoid process, not elsewhere classified',
#  '751': 'Intraoperative and postprocedural complications and disorders of eye and adnexa, not elsewhere classified',
#  '752': 'Intraoperative and postprocedural complications and disorders of genitourinary system, not elsewhere classified',
#  '753': 'Intraoperative and postprocedural complications and disorders of musculoskeletal system, not elsewhere classified',
#  '754': 'Intraoperative and postprocedural complications and disorders of nervous system, not elsewhere classified',
#  '755': 'Intraoperative and postprocedural complications and disorders of respiratory system, not elsewhere classified',
#  '756': 'Intraoperative and postprocedural complications of skin and subcutaneous tissue',
#  '757': 'Intraoperative and postprocedural complications of the spleen',
#  '758': 'Intraoperative complications of endocrine system',
#  '759': 'Iodine-deficiency related thyroid disorders and allied conditions',
#  '760': 'Iridocyclitis',
#  '761': 'Iron deficiency anemia',
#  '762': 'Irritable bowel syndrome',
#  '763': 'Irritant contact dermatitis',
#  '764': 'Isolated proteinuria with specified morphological lesion',
#  '765': 'Juvenile arthritis',
#  '766': 'Juvenile osteochondrosis of hip and pelvis',
#  '767': "Kaposi's sarcoma",
#  '768': 'Keratitis',
#  '769': 'Kernicterus',
#  '770': 'Kyphosis and lordosis',
#  '771': 'Labor and delivery complicated by intrapartum hemorrhage, not elsewhere classified',
#  '772': 'Labor and delivery complicated by umbilical cord complications',
#  '773': 'Lack of expected normal physiological development in childhood and adults',
#  '774': 'Lactose intolerance',
#  '775': 'Late pregnancy',
#  '776': 'Late syphilis',
#  '777': 'Legal intervention',
#  '778': 'Leiomyoma of uterus',
#  '779': 'Leishmaniasis',
#  '780': "Leprosy [Hansen's disease]",
#  '781': 'Leptospirosis',
#  '782': 'Leukemia of unspecified cell type',
#  '783': 'Lichen planus',
#  '784': 'Lichen simplex chronicus and prurigo',
#  '785': 'Listeriosis',
#  '786': 'Liveborn infants according to place of birth and type of delivery',
#  '787': 'Localized swelling, mass and lump of skin and subcutaneous tissue',
#  '788': 'Long labor',
#  '789': 'Long term (current) drug therapy',
#  '790': 'Lupus erythematosus',
#  '791': 'Lymphoid leukemia',
#  '792': 'Major depressive disorder, recurrent',
#  '793': 'Major depressive disorder, single episode',
#  '794': 'Malaise and fatigue',
#  '795': 'Male erectile dysfunction',
#  '796': 'Male infertility',
#  '797': 'Malignant immunoproliferative diseases and certain other B-cell lymphomas',
#  '798': 'Malignant melanoma of skin',
#  '799': 'Malignant neoplasm of accessory sinuses',
#  '800': 'Malignant neoplasm of adrenal gland',
#  '801': 'Malignant neoplasm of anus and anal canal',
#  '802': 'Malignant neoplasm of bladder',
#  '803': 'Malignant neoplasm of bone and articular cartilage of limbs',
#  '804': 'Malignant neoplasm of bone and articular cartilage of other and unspecified sites',
#  '805': 'Malignant neoplasm of brain',
#  '806': 'Malignant neoplasm of breast',
#  '807': 'Malignant neoplasm of bronchus and lung',
#  '808': 'Malignant neoplasm of cervix uteri',
#  '809': 'Malignant neoplasm of colon',
#  '810': 'Malignant neoplasm of corpus uteri',
#  '811': 'Malignant neoplasm of esophagus',
#  '812': 'Malignant neoplasm of eye and adnexa',
#  '813': 'Malignant neoplasm of floor of mouth',
#  '814': 'Malignant neoplasm of gum',
#  '815': 'Malignant neoplasm of heart, mediastinum and pleura',
#  '816': 'Malignant neoplasm of hypopharynx',
#  '817': 'Malignant neoplasm of kidney, except renal pelvis',
#  '818': 'Malignant neoplasm of larynx',
#  '819': 'Malignant neoplasm of lip',
#  '820': 'Malignant neoplasm of liver and intrahepatic bile ducts',
#  '821': 'Malignant neoplasm of meninges',
#  '822': 'Malignant neoplasm of nasal cavity and middle ear',
#  '823': 'Malignant neoplasm of nasopharynx',
#  '824': 'Malignant neoplasm of oropharynx',
#  '825': 'Malignant neoplasm of other and ill-defined digestive organs',
#  '826': 'Malignant neoplasm of other and ill-defined sites',
#  '827': 'Malignant neoplasm of other and ill-defined sites in the lip, oral cavity and pharynx',
#  '828': 'Malignant neoplasm of other and ill-defined sites in the respiratory system and intrathoracic organs',
#  '829': 'Malignant neoplasm of other and unspecified female genital organs',
#  '830': 'Malignant neoplasm of other and unspecified major salivary glands',
#  '831': 'Malignant neoplasm of other and unspecified male genital organs',
#  '832': 'Malignant neoplasm of other and unspecified parts of biliary tract',
#  '833': 'Malignant neoplasm of other and unspecified parts of mouth',
#  '834': 'Malignant neoplasm of other and unspecified parts of tongue',
#  '835': 'Malignant neoplasm of other and unspecified urinary organs',
#  '836': 'Malignant neoplasm of other connective and soft tissue',
#  '837': 'Malignant neoplasm of other endocrine glands and related structures',
#  '838': 'Malignant neoplasm of ovary',
#  '839': 'Malignant neoplasm of palate',
#  '840': 'Malignant neoplasm of pancreas',
#  '841': 'Malignant neoplasm of penis',
#  '842': 'Malignant neoplasm of peripheral nerves and autonomic nervous system',
#  '843': 'Malignant neoplasm of renal pelvis',
#  '844': 'Malignant neoplasm of retroperitoneum and peritoneum',
#  '845': 'Malignant neoplasm of small intestine',
#  '846': 'Malignant neoplasm of spinal cord, cranial nerves and other parts of central nervous system',
#  '847': 'Malignant neoplasm of stomach',
#  '848': 'Malignant neoplasm of testis',
#  '849': 'Malignant neoplasm of tonsil',
#  '850': 'Malignant neoplasm of ureter',
#  '851': 'Malignant neoplasm of vulva',
#  '852': 'Malignant neoplasm without specification of site',
#  '853': 'Malignant neuroendocrine tumors',
#  '854': 'Malnutrition in pregnancy, childbirth and the puerperium',
#  '855': 'Manic episode',
#  '856': 'Mastoiditis and related conditions',
#  '857': 'Maternal care for abnormality of pelvic organs',
#  '858': 'Maternal care for disproportion',
#  '859': 'Maternal care for known or suspected fetal abnormality and damage',
#  '860': 'Maternal care for malpresentation of fetus',
#  '861': 'Maternal care for other conditions predominantly related to pregnancy',
#  '862': 'Maternal care for other fetal problems',
#  '863': 'Maternal infectious and parasitic diseases classifiable elsewhere but complicating pregnancy, childbirth and the puerperium',
#  '864': 'Maternal malignant neoplasms, traumatic injuries and abuse classifiable elsewhere but complicating pregnancy, childbirth and the puerperium',
#  '865': 'Mature T/NK-cell lymphomas',
#  '866': 'Measles',
#  '867': 'Melanocytic nevi',
#  '868': 'Melanoma in situ',
#  '869': 'Meningitis due to other and unspecified causes',
#  '870': 'Meningococcal infection',
#  '871': 'Menopausal and other perimenopausal disorders',
#  '872': 'Merkel cell carcinoma',
#  '873': 'Mesothelioma',
#  '874': 'Metabolic acidemia in newborn',
#  '875': 'Methemoglobinemia',
#  '876': 'Migraine',
#  '877': 'Miliary tuberculosis',
#  '878': 'Military operations',
#  '879': 'Monocytic leukemia',
#  '880': 'Mononeuropathies of lower limb',
#  '881': 'Mononeuropathies of upper limb',
#  '882': 'Monosomies and deletions from the autosomes, not elsewhere classified',
#  '883': 'Mosquito-borne viral encephalitis',
#  '884': 'Motor- or nonmotor-vehicle accident, type of vehicle unspecified',
#  '885': 'Motorcycle rider injured in collision with car, pick-up truck or van',
#  '886': 'Motorcycle rider injured in collision with fixed or stationary object',
#  '887': 'Motorcycle rider injured in collision with heavy transport vehicle or bus',
#  '888': 'Motorcycle rider injured in collision with other nonmotor vehicle',
#  '889': 'Motorcycle rider injured in collision with pedal cycle',
#  '890': 'Motorcycle rider injured in collision with pedestrian or animal',
#  '891': 'Motorcycle rider injured in collision with railway train or railway vehicle',
#  '892': 'Motorcycle rider injured in collision with two- or three-wheeled motor vehicle',
#  '893': 'Motorcycle rider injured in noncollision transport accident',
#  '894': 'Motorcycle rider injured in other and unspecified transport accidents',
#  '895': 'Multiple gestation',
#  '896': 'Multiple myeloma and malignant plasma cell neoplasms',
#  '897': 'Multiple valve diseases',
#  '898': 'Mumps',
#  '899': 'Myasthenia gravis and other myoneural disorders',
#  '900': 'Mycetoma',
#  '901': 'Myelodysplastic syndromes',
#  '902': 'Myeloid leukemia',
#  '903': 'Myiasis',
#  '904': 'Myositis',
#  '905': 'Nail disorders',
#  '906': 'Nasal polyp',
#  '907': 'Nausea and vomiting',
#  '908': 'Necrotizing enterocolitis of newborn',
#  '909': 'Neonatal aspiration',
#  '910': 'Neonatal jaundice due to other excessive hemolysis',
#  '911': 'Neonatal jaundice from other and unspecified causes',
#  '912': 'Neoplasm of uncertain behavior of brain and central nervous system',
#  '913': 'Neoplasm of uncertain behavior of endocrine glands',
#  '914': 'Neoplasm of uncertain behavior of female genital organs',
#  '915': 'Neoplasm of uncertain behavior of male genital organs',
#  '916': 'Neoplasm of uncertain behavior of meninges',
#  '917': 'Neoplasm of uncertain behavior of middle ear and respiratory and intrathoracic organs',
#  '918': 'Neoplasm of uncertain behavior of oral cavity and digestive organs',
#  '919': 'Neoplasm of uncertain behavior of other and unspecified sites',
#  '920': 'Neoplasm of uncertain behavior of urinary organs',
#  '921': 'Neoplasms of unspecified behavior',
#  '922': 'Nephrotic syndrome',
#  '923': 'Nerve root and plexus disorders',
#  '924': 'Neurological devices associated with adverse incidents',
#  '925': 'Neuromuscular dysfunction of bladder, not elsewhere classified',
#  '926': 'Neutropenia',
#  '927': 'Newborn affected by complications of placenta, cord and membranes',
#  '928': 'Newborn affected by intrauterine (fetal) blood loss',
#  '929': 'Newborn affected by maternal complications of pregnancy',
#  '930': 'Newborn affected by maternal conditions that may be unrelated to present pregnancy',
#  '931': 'Newborn affected by noxious substances transmitted via placenta or breast milk',
#  '932': 'Newborn affected by other complications of labor and delivery',
#  '933': 'Nicotine dependence',
#  '934': 'Nocardiosis',
#  '935': 'Non-follicular lymphoma',
#  '936': 'Non-pressure chronic ulcer of lower limb, not elsewhere classified',
#  '937': 'Noninflammatory disorders of ovary, fallopian tube and broad ligament',
#  '938': 'Noninflammatory disorders of testis',
#  '939': 'Nonrheumatic aortic valve disorders',
#  '940': 'Nonrheumatic mitral valve disorders',
#  '941': 'Nonrheumatic pulmonary valve disorders',
#  '942': 'Nonrheumatic tricuspid valve disorders',
#  '943': 'Nonspecific lymphadenitis',
#  '944': 'Nonsuppurative otitis media',
#  '945': "Nontraffic accident of specified type but victim's mode of transport unknown",
#  '946': 'Nontraumatic intracerebral hemorrhage',
#  '947': 'Nontraumatic subarachnoid hemorrhage',
#  '948': 'Nystagmus and other irregular eye movements',
#  '949': 'Obsessive-compulsive disorder',
#  '950': 'Obstetric and gynecological devices associated with adverse incidents',
#  '951': 'Obstetric embolism',
#  '952': 'Obstructed labor due to malposition and malpresentation of fetus',
#  '953': 'Obstructed labor due to maternal pelvic abnormality',
#  '954': 'Obstructive and reflux uropathy',
#  '955': 'Occlusion and stenosis of cerebral arteries, not resulting in cerebral infarction',
#  '956': 'Occlusion and stenosis of precerebral arteries, not resulting in cerebral infarction',
#  '957': 'Occupant of heavy transport vehicle injured in collision with car, pick-up truck or van',
#  '958': 'Occupant of heavy transport vehicle injured in collision with fixed or stationary object',
#  '959': 'Occupant of heavy transport vehicle injured in collision with heavy transport vehicle or bus',
#  '960': 'Occupant of heavy transport vehicle injured in collision with other nonmotor vehicle',
#  '961': 'Occupant of heavy transport vehicle injured in collision with pedal cycle',
#  '962': 'Occupant of heavy transport vehicle injured in collision with pedestrian or animal',
#  '963': 'Occupant of heavy transport vehicle injured in collision with railway train or railway vehicle',
#  '964': 'Occupant of heavy transport vehicle injured in collision with two- or three-wheeled motor vehicle',
#  '965': 'Occupant of heavy transport vehicle injured in noncollision transport accident',
#  '966': 'Occupant of heavy transport vehicle injured in other and unspecified transport accidents',
#  '967': 'Occupant of pick-up truck or van injured in collision with car, pick-up truck or van',
#  '968': 'Occupant of pick-up truck or van injured in collision with fixed or stationary object',
#  '969': 'Occupant of pick-up truck or van injured in collision with heavy transport vehicle or bus',
#  '970': 'Occupant of pick-up truck or van injured in collision with other nonmotor vehicle',
#  '971': 'Occupant of pick-up truck or van injured in collision with pedal cycle',
#  '972': 'Occupant of pick-up truck or van injured in collision with pedestrian or animal',
#  '973': 'Occupant of pick-up truck or van injured in collision with railway train or railway vehicle',
#  '974': 'Occupant of pick-up truck or van injured in collision with two- or three-wheeled motor vehicle',
#  '975': 'Occupant of pick-up truck or van injured in noncollision transport accident',
#  '976': 'Occupant of pick-up truck or van injured in other and unspecified transport accidents',
#  '977': 'Occupant of powered streetcar injured in transport accident',
#  '978': 'Occupant of railway train or railway vehicle injured in transport accident',
#  '979': 'Occupant of special all-terrain or other off-road motor vehicle, injured in transport accident',
#  '980': 'Occupant of special construction vehicle injured in transport accident',
#  '981': 'Occupant of special vehicle mainly used in agriculture injured in transport accident',
#  '982': 'Occupant of special vehicle mainly used on industrial premises injured in transport accident',
#  '983': 'Occupant of three-wheeled motor vehicle injured in collision with car, pick-up truck or van',
#  '984': 'Occupant of three-wheeled motor vehicle injured in collision with fixed or stationary object',
#  '985': 'Occupant of three-wheeled motor vehicle injured in collision with heavy transport vehicle or bus',
#  '986': 'Occupant of three-wheeled motor vehicle injured in collision with other nonmotor vehicle',
#  '987': 'Occupant of three-wheeled motor vehicle injured in collision with pedal cycle',
#  '988': 'Occupant of three-wheeled motor vehicle injured in collision with pedestrian or animal',
#  '989': 'Occupant of three-wheeled motor vehicle injured in collision with railway train or railway vehicle',
#  '990': 'Occupant of three-wheeled motor vehicle injured in collision with two- or three-wheeled motor vehicle',
#  '991': 'Occupant of three-wheeled motor vehicle injured in noncollision transport accident',
#  '992': 'Occupant of three-wheeled motor vehicle injured in other and unspecified transport accidents',
#  '993': 'Occupational exposure to risk factors',
#  '994': 'Omphalitis of newborn',
#  '995': 'Onchocerciasis',
#  '996': 'Open wound of abdomen, lower back, pelvis and external genitals',
#  '997': 'Open wound of ankle, foot and toes',
#  '998': 'Open wound of elbow and forearm',
#  '999': 'Open wound of head',
#  ...}

# %%
labeler[0].get(str(model_final(["Injure in the back while it was driven a VAN"])[0]))
# Out:
# 'Occupant of special all-terrain or other off-road motor vehicle, injured in transport accident'

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

# %%
model_ = AutoModelForSequenceClassification.from_pretrained("rjac/setfit-ST-ICD10-L3")
# Out:
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at rjac/setfit-ST-ICD10-L3 were not used when initializing MPNetForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing MPNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MPNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at rjac/setfit-ST-ICD10-L3 and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# MPNetForSequenceClassification(
#   (mpnet): MPNetModel(
#     (embeddings): MPNetEmbeddings(
#       (word_embeddings): Embedding(30527, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): MPNetEncoder(
#       (layer): ModuleList(
#         (0): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): MPNetLayer(
#           (attention): MPNetAttention(
#             (attn): MPNetSelfAttention(
#               (q): Linear(in_features=768, out_features=768, bias=True)
#               (k): Linear(in_features=768, out_features=768, bias=True)
#               (v): Linear(in_features=768, out_features=768, bias=True)
#               (o): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (intermediate): MPNetIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): MPNetOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (relative_attention_bias): Embedding(32, 12)
#     )
#   )
#   (classifier): MPNetClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )
