# %%
# %%capture
# !pip install simple-icd-10 
# !pip install simple-icd-10-cm
# !pip install datasets transformers

# %%
import json 
import pandas as pd
import simple_icd_10_cm as icd
from datasets import load_dataset,Dataset
from sklearn.preprocessing import LabelEncoder
import joblib
from sklearn import metrics
import numpy as np
from transformers import (
    AutoTokenizer
    ,AutoModelForSequenceClassification
    ,DataCollatorWithPadding
    ,TrainingArguments
    ,Trainer
    ,pipeline
)

# %%
MODEL_VERSION="rjac/setfit-ST-ICD10-L3"

# %%
df = pd.DataFrame(json.load(open("/content/icd_json.json","r"))) 
df["text"] = df.text.apply(lambda i: i.get("codeDescription"))
df["icd-l3"] = df.icd10Code.str[0:3]
df["icd_group"] = df["icd-l3"].apply(icd.get_parent)
df["icd_group_description"] = df["icd_group"].apply(icd.get_description)
df["icd_general_group"] = df["icd_group"].apply(icd.get_parent)
df["icd_general_group_description"] = df["icd_general_group"].apply(icd.get_description)

# %%
df["labels"] = df["icd_group_description"]

# %%
df[["text","icd_group_description","labels"]].to_json("icd_dataset.jsonl",orient="records",lines=True)

# %%
dataset = load_dataset("json",data_files="/content/icd_dataset.jsonl",split="train")
# Out:
# WARNING:datasets.builder:Using custom data configuration default-e0479e0881c49dd3
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-e0479e0881c49dd3/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-e0479e0881c49dd3/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab. Subsequent calls will reuse this data.

# %%
dataset = dataset.class_encode_column("labels")
# Out:
# Casting to class labels:   0%|          | 0/72 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/8 [00:00<?, ?ba/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_VERSION)
# Out:
# Downloading:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
def tokenize_text(batch):
    texts = batch["text"]
    return tokenizer(texts,truncation=True)

# %%
tokenized_dataset = dataset.map(tokenize_text,remove_columns=['text', 'icd_group_description'])
# Out:
#   0%|          | 0/71480 [00:00<?, ?ex/s]

# %%
tokenized_dataset = tokenized_dataset.train_test_split(test_size=0.2)

# %%
train_dataset = tokenized_dataset["train"].shuffle(7854)
validation_dataset = tokenized_dataset["test"]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 57184
# })

# %%
target_feature = tokenized_dataset["train"].features["labels"]
num_classes = target_feature.num_classes
label_names = target_feature.names

id2label = {str(i): label for i, label in enumerate(label_names)}
label2id = {v: k for k, v in id2label.items()}

# %%
#id2icd = {i:l for i,l in enumerate(label_encoder.classes_)}
#icd2id = {l:i for i,l in enumerate(label_encoder.classes_)}

# %%
model = AutoModelForSequenceClassification.from_pretrained(MODEL_VERSION,num_labels=num_classes,id2label=id2label,label2id=label2id)
# Out:
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at rjac/setfit-ST-ICD10-L3 were not used when initializing MPNetForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing MPNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MPNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at rjac/setfit-ST-ICD10-L3 and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
num_freeze_param = 190
for i,p in enumerate(model.mpnet.parameters()):
    if i < num_freeze_param:
        p.requires_grad = False

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
batch_size=512

# %%
args = TrainingArguments(
    "model",
    evaluation_strategy="epoch",
    overwrite_output_dir=True,
    save_total_limit = 3,
    save_strategy="epoch",
    learning_rate=1e-3,
    num_train_epochs=10,
    weight_decay=0.005,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size*2
)

# %%
def compute_metrics(eval_pred):
    logits_, labels_ = eval_pred
    predictions = np.argmax(logits_, axis=-1)

    accuracy = metrics.accuracy_score(labels_, predictions)
    f1_score_micro = metrics.f1_score(labels_, predictions, average='micro')
    f1_score_macro = metrics.f1_score(labels_, predictions, average='macro')

    return {"accuracy": accuracy, "f1_score_micro": f1_score_micro, "f1_score_macro": f1_score_macro}

# %%
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer
)
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 57184
#   Num Epochs = 10
#   Instantaneous batch size per device = 512
#   Total train batch size (w. parallel, distributed & accumulation) = 512
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1120
# You're using a MPNetTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1120' max='1120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1120/1120 48:56, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Score Micro</th>
#       <th>F1 Score Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.813335</td>
#       <td>0.730834</td>
#       <td>0.730834</td>
#       <td>0.456656</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.529755</td>
#       <td>0.813514</td>
#       <td>0.813514</td>
#       <td>0.588727</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.407093</td>
#       <td>0.864158</td>
#       <td>0.864158</td>
#       <td>0.649337</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.357667</td>
#       <td>0.882275</td>
#       <td>0.882275</td>
#       <td>0.690422</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.838800</td>
#       <td>0.311951</td>
#       <td>0.892068</td>
#       <td>0.892068</td>
#       <td>0.732508</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.838800</td>
#       <td>0.290250</td>
#       <td>0.903400</td>
#       <td>0.903400</td>
#       <td>0.748269</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.838800</td>
#       <td>0.253276</td>
#       <td>0.920817</td>
#       <td>0.920817</td>
#       <td>0.785354</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.838800</td>
#       <td>0.221692</td>
#       <td>0.930820</td>
#       <td>0.930820</td>
#       <td>0.802538</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.366100</td>
#       <td>0.209190</td>
#       <td>0.937045</td>
#       <td>0.937045</td>
#       <td>0.819868</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.366100</td>
#       <td>0.199223</td>
#       <td>0.941662</td>
#       <td>0.941662</td>
#       <td>0.829331</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-112
# Configuration saved in model/checkpoint-112/config.json
# Model weights saved in model/checkpoint-112/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-112/tokenizer_config.json
# Special tokens file saved in model/checkpoint-112/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-224
# Configuration saved in model/checkpoint-224/config.json
# Model weights saved in model/checkpoint-224/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-224/tokenizer_config.json
# Special tokens file saved in model/checkpoint-224/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-336
# Configuration saved in model/checkpoint-336/config.json
# Model weights saved in model/checkpoint-336/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-336/tokenizer_config.json
# Special tokens file saved in model/checkpoint-336/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-448
# Configuration saved in model/checkpoint-448/config.json
# Model weights saved in model/checkpoint-448/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-448/tokenizer_config.json
# Special tokens file saved in model/checkpoint-448/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-112] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-560
# Configuration saved in model/checkpoint-560/config.json
# Model weights saved in model/checkpoint-560/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-560/tokenizer_config.json
# Special tokens file saved in model/checkpoint-560/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-224] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-672
# Configuration saved in model/checkpoint-672/config.json
# Model weights saved in model/checkpoint-672/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-672/tokenizer_config.json
# Special tokens file saved in model/checkpoint-672/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-336] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-784
# Configuration saved in model/checkpoint-784/config.json
# Model weights saved in model/checkpoint-784/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-784/tokenizer_config.json
# Special tokens file saved in model/checkpoint-784/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-448] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-896
# Configuration saved in model/checkpoint-896/config.json
# Model weights saved in model/checkpoint-896/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-896/tokenizer_config.json
# Special tokens file saved in model/checkpoint-896/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-560] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-1008
# Configuration saved in model/checkpoint-1008/config.json
# Model weights saved in model/checkpoint-1008/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-1008/tokenizer_config.json
# Special tokens file saved in model/checkpoint-1008/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-672] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 14296
#   Batch size = 1024
# Saving model checkpoint to model/checkpoint-1120
# Configuration saved in model/checkpoint-1120/config.json
# Model weights saved in model/checkpoint-1120/pytorch_model.bin
# tokenizer config file saved in model/checkpoint-1120/tokenizer_config.json
# Special tokens file saved in model/checkpoint-1120/special_tokens_map.json
# Deleting older checkpoint [model/checkpoint-784] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1120, training_loss=0.5692728723798479, metrics={'train_runtime': 2941.4099, 'train_samples_per_second': 194.41, 'train_steps_per_second': 0.381, 'total_flos': 1.1826999557225664e+16, 'train_loss': 0.5692728723798479, 'epoch': 10.0})

# %%
trainer.save_model("/content/drive/MyDrive/other/icd_stclassification")
# Out:
# Saving model checkpoint to /content/drive/MyDrive/other/icd_stclassification
# Configuration saved in /content/drive/MyDrive/other/icd_stclassification/config.json
# Model weights saved in /content/drive/MyDrive/other/icd_stclassification/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/other/icd_stclassification/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/other/icd_stclassification/special_tokens_map.json

# %%
model_ = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/other/icd_stclassification")
tokenizer_ = AutoTokenizer.from_pretrained("/content/drive/MyDrive/other/icd_stclassification")
# Out:
# loading configuration file /content/drive/MyDrive/other/icd_stclassification/config.json
# Model config MPNetConfig {
#   "_name_or_path": "/content/drive/MyDrive/other/icd_stclassification",
#   "architectures": [
#     "MPNetForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "Abnormal findings on diagnostic imaging and in function studies, without diagnosis (R90-R94)",
#     "1": "Abnormal findings on examination of blood, without diagnosis (R70-R79)",
#     "2": "Abnormal findings on examination of other body fluids, substances and tissues, without diagnosis (R83-R89)",
#     "3": "Abnormal findings on examination of urine, without diagnosis (R80-R82)",
#     "4": "Abnormal tumor markers",
#     "5": "Accidental exposure to other specified factors (X52-X58)",
#     "6": "Accidental non-transport drowning and submersion (W65-W74)",
#     "7": "Acute kidney failure and chronic kidney disease (N17-N19)",
#     "8": "Acute rheumatic fever (I00-I02)",
#     "9": "Acute upper respiratory infections (J00-J06)",
#     "10": "Air and space transport accidents (V95-V97)",
#     "11": "Anxiety, dissociative, stress-related, somatoform and other nonpsychotic mental disorders (F40-F48)",
#     "12": "Aplastic and other anemias and other bone marrow failure syndromes (D60-D64)",
#     "13": "Arthropod-borne viral fevers and viral hemorrhagic fevers (A90-A99)",
#     "14": "Assault (X92-Y09)",
#     "15": "Autoinflammatory syndromes",
#     "16": "Bacterial and viral infectious agents (B95-B97)",
#     "17": "Behavioral and emotional disorders with onset usually occurring in childhood and adolescence (F90-F98)",
#     "18": "Behavioral syndromes associated with physiological disturbances and physical factors (F50-F59)",
#     "19": "Benign neoplasms, except benign neuroendocrine tumors (D10-D36)",
#     "20": "Benign neuroendocrine tumors",
#     "21": "Biomechanical lesions, not elsewhere classified",
#     "22": "Birth trauma (P10-P15)",
#     "23": "Blood type",
#     "24": "Body mass index [BMI]",
#     "25": "Bullous disorders (L10-L14)",
#     "26": "Burns and corrosions confined to eye and internal organs (T26-T28)",
#     "27": "Burns and corrosions of external body surface, specified by site (T20-T25)",
#     "28": "Burns and corrosions of multiple and unspecified body regions (T30-T32)",
#     "29": "Bus occupant injured in transport accident (V70-V79)",
#     "30": "Car occupant injured in transport accident (V40-V49)",
#     "31": "Cerebral palsy and other paralytic syndromes (G80-G83)",
#     "32": "Cerebrovascular diseases (I60-I69)",
#     "33": "Certain disorders involving the immune mechanism (D80-D89)",
#     "34": "Certain early complications of trauma, not elsewhere classified",
#     "35": "Certain zoonotic bacterial diseases (A20-A28)",
#     "36": "Chondropathies (M91-M94)",
#     "37": "Chromosomal abnormalities, not elsewhere classified (Q90-Q99)",
#     "38": "Chronic lower respiratory diseases (J40-J47)",
#     "39": "Chronic rheumatic heart diseases (I05-I09)",
#     "40": "Cleft lip and cleft palate (Q35-Q37)",
#     "41": "Coagulation defects, purpura and other hemorrhagic conditions (D65-D69)",
#     "42": "Complications of labor and delivery (O60-O77)",
#     "43": "Complications of surgical and medical care, not elsewhere classified (T80-T88)",
#     "44": "Complications predominantly related to the puerperium (O85-O92)",
#     "45": "Conditions involving the integument and temperature regulation of newborn (P80-P83)",
#     "46": "Congenital malformations and deformations of the musculoskeletal system (Q65-Q79)",
#     "47": "Congenital malformations of eye, ear, face and neck (Q10-Q18)",
#     "48": "Congenital malformations of genital organs (Q50-Q56)",
#     "49": "Congenital malformations of the circulatory system (Q20-Q28)",
#     "50": "Congenital malformations of the nervous system (Q00-Q07)",
#     "51": "Congenital malformations of the respiratory system (Q30-Q34)",
#     "52": "Congenital malformations of the urinary system (Q60-Q64)",
#     "53": "Contact with heat and hot substances (X10-X19)",
#     "54": "Deforming dorsopathies (M40-M43)",
#     "55": "Demyelinating diseases of the central nervous system (G35-G37)",
#     "56": "Dentofacial anomalies [including malocclusion] and other disorders of jaw (M26-M27)",
#     "57": "Dermatitis and eczema (L20-L30)",
#     "58": "Diabetes mellitus (E08-E13)",
#     "59": "Digestive system disorders of newborn (P76-P78)",
#     "60": "Diseases of appendix (K35-K38)",
#     "61": "Diseases of arteries, arterioles and capillaries (I70-I79)",
#     "62": "Diseases of esophagus, stomach and duodenum (K20-K31)",
#     "63": "Diseases of external ear (H60-H62)",
#     "64": "Diseases of inner ear (H80-H83)",
#     "65": "Diseases of liver (K70-K77)",
#     "66": "Diseases of male genital organs (N40-N53)",
#     "67": "Diseases of middle ear and mastoid (H65-H75)",
#     "68": "Diseases of myoneural junction and muscle (G70-G73)",
#     "69": "Diseases of oral cavity and salivary glands (K00-K14)",
#     "70": "Diseases of peritoneum and retroperitoneum (K65-K68)",
#     "71": "Diseases of veins, lymphatic vessels and lymph nodes, not elsewhere classified (I80-I89)",
#     "72": "Disorders of adult personality and behavior (F60-F69)",
#     "73": "Disorders of bone density and structure (M80-M85)",
#     "74": "Disorders of breast (N60-N65)",
#     "75": "Disorders of choroid and retina (H30-H36)",
#     "76": "Disorders of conjunctiva (H10-H11)",
#     "77": "Disorders of eyelid, lacrimal system and orbit (H00-H05)",
#     "78": "Disorders of gallbladder, biliary tract and pancreas (K80-K87)",
#     "79": "Disorders of lens (H25-H28)",
#     "80": "Disorders of muscles (M60-M63)",
#     "81": "Disorders of newborn related to length of gestation and fetal growth (P05-P08)",
#     "82": "Disorders of ocular muscles, binocular movement, accommodation and refraction (H49-H52)",
#     "83": "Disorders of optic nerve and visual pathways (H46-H47)",
#     "84": "Disorders of other endocrine glands (E20-E35)",
#     "85": "Disorders of sclera, cornea, iris and ciliary body (H15-H22)",
#     "86": "Disorders of skin appendages (L60-L75)",
#     "87": "Disorders of synovium and tendon (M65-M67)",
#     "88": "Disorders of thyroid gland (E00-E07)",
#     "89": "Disorders of vitreous body and globe (H43-H44)",
#     "90": "Edema, proteinuria and hypertensive disorders in pregnancy, childbirth and the puerperium (O10-O16)",
#     "91": "Effects of foreign body entering through natural orifice (T15-T19)",
#     "92": "Encounters for other specific health care (Z40-Z53)",
#     "93": "Episodic and paroxysmal disorders (G40-G47)",
#     "94": "Estrogen receptor status",
#     "95": "Event of undetermined intent (Y21-Y33)",
#     "96": "Exposure to animate mechanical forces (W50-W64)",
#     "97": "Exposure to electric current, radiation and extreme ambient air temperature and pressure (W85-W99)",
#     "98": "Exposure to forces of nature (X30-X39)",
#     "99": "Exposure to inanimate mechanical forces (W20-W49)",
#     "100": "Exposure to smoke, fire and flames (X00-X08)",
#     "101": "Extrapyramidal and movement disorders (G20-G26)",
#     "102": "Frostbite (T33-T34)",
#     "103": "General symptoms and signs (R50-R69)",
#     "104": "Genetic carrier and genetic susceptibility to disease (Z14-Z15)",
#     "105": "Glaucoma (H40-H42)",
#     "106": "Glomerular diseases (N00-N08)",
#     "107": "Helminthiases (B65-B83)",
#     "108": "Hemolytic anemias (D55-D59)",
#     "109": "Hemorrhagic and hematological disorders of newborn (P50-P61)",
#     "110": "Hernia (K40-K46)",
#     "111": "Hormone sensitivity malignancy status",
#     "112": "Hypertensive diseases (I10-I16)",
#     "113": "In situ neoplasms (D00-D09)",
#     "114": "Infections of the skin and subcutaneous tissue (L00-L08)",
#     "115": "Infections specific to the perinatal period (P35-P39)",
#     "116": "Infections with a predominantly sexual mode of transmission (A50-A64)",
#     "117": "Infectious arthropathies (M00-M02)",
#     "118": "Inflammatory diseases of female pelvic organs (N70-N77)",
#     "119": "Inflammatory diseases of the central nervous system (G00-G09)",
#     "120": "Inflammatory polyarthropathies (M05-M14)",
#     "121": "Influenza and pneumonia (J09-J18)",
#     "122": "Injuries to the abdomen, lower back, lumbar spine, pelvis and external genitals (S30-S39)",
#     "123": "Injuries to the ankle and foot (S90-S99)",
#     "124": "Injuries to the elbow and forearm (S50-S59)",
#     "125": "Injuries to the head (S00-S09)",
#     "126": "Injuries to the hip and thigh (S70-S79)",
#     "127": "Injuries to the knee and lower leg (S80-S89)",
#     "128": "Injuries to the neck (S10-S19)",
#     "129": "Injuries to the shoulder and upper arm (S40-S49)",
#     "130": "Injuries to the thorax (S20-S29)",
#     "131": "Injuries to the wrist, hand and fingers (S60-S69)",
#     "132": "Injury of unspecified body region",
#     "133": "Intentional self-harm (X71-X83)",
#     "134": "Intestinal infectious diseases (A00-A09)",
#     "135": "Intraoperative and postprocedural complications and disorders of ear and mastoid process, not elsewhere classified",
#     "136": "Intraoperative and postprocedural complications and disorders of eye and adnexa, not elsewhere classified",
#     "137": "Intraoperative and postprocedural complications and disorders of genitourinary system, not elsewhere classified",
#     "138": "Intraoperative and postprocedural complications and disorders of musculoskeletal system, not elsewhere classified",
#     "139": "Intraoperative and postprocedural complications and disorders of respiratory system, not elsewhere classified",
#     "140": "Intraoperative and postprocedural complications of skin and subcutaneous tissue",
#     "141": "Intraoperative and postprocedural complications of the spleen",
#     "142": "Intraoperative complications of endocrine system",
#     "143": "Ischemic heart diseases (I20-I25)",
#     "144": "Legal intervention, operations of war, military operations, and terrorism (Y35-Y38)",
#     "145": "Lung diseases due to external agents (J60-J70)",
#     "146": "Malignant neoplasm of breast",
#     "147": "Malignant neoplasms of bone and articular cartilage (C40-C41)",
#     "148": "Malignant neoplasms of digestive organs (C15-C26)",
#     "149": "Malignant neoplasms of eye, brain and other parts of central nervous system (C69-C72)",
#     "150": "Malignant neoplasms of female genital organs (C51-C58)",
#     "151": "Malignant neoplasms of ill-defined, other secondary and unspecified sites (C76-C80)",
#     "152": "Malignant neoplasms of lip, oral cavity and pharynx (C00-C14)",
#     "153": "Malignant neoplasms of lymphoid, hematopoietic and related tissue (C81-C96)",
#     "154": "Malignant neoplasms of male genital organs (C60-C63)",
#     "155": "Malignant neoplasms of mesothelial and soft tissue (C45-C49)",
#     "156": "Malignant neoplasms of respiratory and intrathoracic organs (C30-C39)",
#     "157": "Malignant neoplasms of thyroid and other endocrine glands (C73-C75)",
#     "158": "Malignant neoplasms of urinary tract (C64-C68)",
#     "159": "Malignant neuroendocrine tumors",
#     "160": "Malnutrition (E40-E46)",
#     "161": "Maternal care related to the fetus and amniotic cavity and possible delivery problems (O30-O48)",
#     "162": "Medical devices associated with adverse incidents in diagnostic and therapeutic use (Y70-Y82)",
#     "163": "Melanoma and other malignant neoplasms of skin (C43-C44)",
#     "164": "Mental and behavioral disorders due to psychoactive substance use (F10-F19)",
#     "165": "Mental disorders due to known physiological conditions (F01-F09)",
#     "166": "Metabolic disorders (E70-E88)",
#     "167": "Misadventures to patients during surgical and medical care (Y62-Y69)",
#     "168": "Mood [affective] disorders (F30-F39)",
#     "169": "Motorcycle rider injured in transport accident (V20-V29)",
#     "170": "Mycoses (B35-B49)",
#     "171": "Neoplasms of uncertain behavior, polycythemia vera and myelodysplastic syndromes (D37-D48)",
#     "172": "Neoplasms of unspecified behavior",
#     "173": "Nerve, nerve root and plexus disorders (G50-G59)",
#     "174": "Newborn affected by maternal factors and by complications of pregnancy, labor, and delivery (P00-P04)",
#     "175": "Noninfective enteritis and colitis (K50-K52)",
#     "176": "Noninflammatory disorders of female genital tract (N80-N98)",
#     "177": "Nutritional anemias (D50-D53)",
#     "178": "Occupant of heavy transport vehicle injured in transport accident (V60-V69)",
#     "179": "Occupant of pick-up truck or van injured in transport accident (V50-V59)",
#     "180": "Occupant of three-wheeled motor vehicle injured in transport accident (V30-V39)",
#     "181": "Osteoarthritis (M15-M19)",
#     "182": "Other acquired deformities of musculoskeletal system and connective tissue",
#     "183": "Other acute lower respiratory infections (J20-J22)",
#     "184": "Other and unspecified disorders of the circulatory system (I95-I99)",
#     "185": "Other and unspecified effects of external causes (T66-T78)",
#     "186": "Other and unspecified infectious diseases",
#     "187": "Other and unspecified transport accidents (V98-V99)",
#     "188": "Other bacterial diseases (A30-A49)",
#     "189": "Other congenital malformations (Q80-Q89)",
#     "190": "Other congenital malformations of the digestive system (Q38-Q45)",
#     "191": "Other degenerative diseases of the nervous system (G30-G32)",
#     "192": "Other diseases caused by chlamydiae (A70-A74)",
#     "193": "Other diseases of intestines (K55-K64)",
#     "194": "Other diseases of the digestive system (K90-K95)",
#     "195": "Other diseases of the pleura (J90-J94)",
#     "196": "Other diseases of the respiratory system (J96-J99)",
#     "197": "Other diseases of the urinary system (N30-N39)",
#     "198": "Other diseases of upper respiratory tract (J30-J39)",
#     "199": "Other disorders of blood and blood-forming organs (D70-D77)",
#     "200": "Other disorders of ear (H90-H94)",
#     "201": "Other disorders of eye and adnexa (H55-H57)",
#     "202": "Other disorders of glucose regulation and pancreatic internal secretion (E15-E16)",
#     "203": "Other disorders of kidney and ureter (N25-N29)",
#     "204": "Other disorders of the nervous system (G89-G99)",
#     "205": "Other disorders of the skin and subcutaneous tissue (L80-L99)",
#     "206": "Other disorders originating in the perinatal period (P90-P96)",
#     "207": "Other dorsopathies (M50-M54)",
#     "208": "Other forms of heart disease (I30-I52)",
#     "209": "Other human herpesviruses",
#     "210": "Other joint disorders (M20-M25)",
#     "211": "Other land transport accidents (V80-V89)",
#     "212": "Other maternal disorders predominantly related to pregnancy (O20-O29)",
#     "213": "Other nutritional deficiencies (E50-E64)",
#     "214": "Other obstetric conditions, not elsewhere classified (O94-O9A)",
#     "215": "Other osteopathies (M86-M90)",
#     "216": "Other respiratory diseases principally affecting the interstitium (J80-J84)",
#     "217": "Other soft tissue disorders (M70-M79)",
#     "218": "Other spirochetal diseases (A65-A69)",
#     "219": "Other viral diseases (B25-B34)",
#     "220": "Overexertion and strenuous or repetitive movements",
#     "221": "Overweight, obesity and other hyperalimentation (E65-E68)",
#     "222": "Papulosquamous disorders (L40-L45)",
#     "223": "Pedal cycle rider injured in transport accident (V10-V19)",
#     "224": "Pedestrian injured in transport accident (V00-V09)",
#     "225": "Pediculosis, acariasis and other infestations (B85-B89)",
#     "226": "Periprosthetic fracture around internal prosthetic joint",
#     "227": "Persons encountering health services for examinations (Z00-Z13)",
#     "228": "Persons encountering health services in circumstances related to reproduction (Z30-Z39)",
#     "229": "Persons encountering health services in other circumstances (Z69-Z76)",
#     "230": "Persons with potential health hazards related to communicable diseases (Z20-Z29)",
#     "231": "Persons with potential health hazards related to family and personal history and certain conditions influencing health status (Z77-Z99)",
#     "232": "Persons with potential health hazards related to socioeconomic and psychosocial circumstances (Z55-Z65)",
#     "233": "Pervasive and specific developmental disorders (F80-F89)",
#     "234": "Poisoning by, adverse effects of and underdosing of drugs, medicaments and biological substances (T36-T50)",
#     "235": "Polyneuropathies and other disorders of the peripheral nervous system (G60-G65)",
#     "236": "Postprocedural endocrine and metabolic complications and disorders, not elsewhere classified",
#     "237": "Pregnancy with abortive outcome (O00-O08)",
#     "238": "Protozoal diseases (B50-B64)",
#     "239": "Pulmonary heart disease and diseases of pulmonary circulation (I26-I28)",
#     "240": "Radiation-related disorders of the skin and subcutaneous tissue (L55-L59)",
#     "241": "Renal tubulo-interstitial diseases (N10-N16)",
#     "242": "Resistance to antimicrobial drugs",
#     "243": "Respiratory and cardiovascular disorders specific to the perinatal period (P19-P29)",
#     "244": "Retained foreign body fragments",
#     "245": "Rickettsioses (A75-A79)",
#     "246": "Schizophrenia, schizotypal, delusional, and other non-mood psychotic disorders (F20-F29)",
#     "247": "Secondary neuroendocrine tumors",
#     "248": "Sequelae of infectious and parasitic diseases (B90-B94)",
#     "249": "Slipping, tripping, stumbling and falls (W00-W19)",
#     "250": "Spondylopathies (M45-M49)",
#     "251": "Supervision of high risk pregnancy",
#     "252": "Supplementary factors related to causes of morbidity classified elsewhere (Y90-Y99)",
#     "253": "Suppurative and necrotic conditions of the lower respiratory tract (J85-J86)",
#     "254": "Surgical and other medical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure (Y83-Y84)",
#     "255": "Symptoms and signs involving cognition, perception, emotional state and behavior (R40-R46)",
#     "256": "Symptoms and signs involving speech and voice (R47-R49)",
#     "257": "Symptoms and signs involving the circulatory and respiratory systems (R00-R09)",
#     "258": "Symptoms and signs involving the digestive system and abdomen (R10-R19)",
#     "259": "Symptoms and signs involving the genitourinary system (R30-R39)",
#     "260": "Symptoms and signs involving the nervous and musculoskeletal systems (R25-R29)",
#     "261": "Symptoms and signs involving the skin and subcutaneous tissue (R20-R23)",
#     "262": "Systemic atrophies primarily affecting the central nervous system (G10-G14)",
#     "263": "Systemic connective tissue disorders (M30-M36)",
#     "264": "Toxic effects of substances chiefly nonmedicinal as to source (T51-T65)",
#     "265": "Transitory endocrine and metabolic disorders specific to newborn (P70-P74)",
#     "266": "Tuberculosis (A15-A19)",
#     "267": "Unspecified multiple injuries",
#     "268": "Urolithiasis (N20-N23)",
#     "269": "Urticaria and erythema (L49-L54)",
#     "270": "Viral and prion infections of the central nervous system (A80-A89)",
#     "271": "Viral hepatitis (B15-B19)",
#     "272": "Viral infections characterized by skin and mucous membrane lesions (B00-B09)",
#     "273": "Visual disturbances and blindness (H53-H54)",
#     "274": "Water transport accidents (V90-V94)"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "Abnormal findings on diagnostic imaging and in function studies, without diagnosis (R90-R94)": "0",
#     "Abnormal findings on examination of blood, without diagnosis (R70-R79)": "1",
#     "Abnormal findings on examination of other body fluids, substances and tissues, without diagnosis (R83-R89)": "2",
#     "Abnormal findings on examination of urine, without diagnosis (R80-R82)": "3",
#     "Abnormal tumor markers": "4",
#     "Accidental exposure to other specified factors (X52-X58)": "5",
#     "Accidental non-transport drowning and submersion (W65-W74)": "6",
#     "Acute kidney failure and chronic kidney disease (N17-N19)": "7",
#     "Acute rheumatic fever (I00-I02)": "8",
#     "Acute upper respiratory infections (J00-J06)": "9",
#     "Air and space transport accidents (V95-V97)": "10",
#     "Anxiety, dissociative, stress-related, somatoform and other nonpsychotic mental disorders (F40-F48)": "11",
#     "Aplastic and other anemias and other bone marrow failure syndromes (D60-D64)": "12",
#     "Arthropod-borne viral fevers and viral hemorrhagic fevers (A90-A99)": "13",
#     "Assault (X92-Y09)": "14",
#     "Autoinflammatory syndromes": "15",
#     "Bacterial and viral infectious agents (B95-B97)": "16",
#     "Behavioral and emotional disorders with onset usually occurring in childhood and adolescence (F90-F98)": "17",
#     "Behavioral syndromes associated with physiological disturbances and physical factors (F50-F59)": "18",
#     "Benign neoplasms, except benign neuroendocrine tumors (D10-D36)": "19",
#     "Benign neuroendocrine tumors": "20",
#     "Biomechanical lesions, not elsewhere classified": "21",
#     "Birth trauma (P10-P15)": "22",
#     "Blood type": "23",
#     "Body mass index [BMI]": "24",
#     "Bullous disorders (L10-L14)": "25",
#     "Burns and corrosions confined to eye and internal organs (T26-T28)": "26",
#     "Burns and corrosions of external body surface, specified by site (T20-T25)": "27",
#     "Burns and corrosions of multiple and unspecified body regions (T30-T32)": "28",
#     "Bus occupant injured in transport accident (V70-V79)": "29",
#     "Car occupant injured in transport accident (V40-V49)": "30",
#     "Cerebral palsy and other paralytic syndromes (G80-G83)": "31",
#     "Cerebrovascular diseases (I60-I69)": "32",
#     "Certain disorders involving the immune mechanism (D80-D89)": "33",
#     "Certain early complications of trauma, not elsewhere classified": "34",
#     "Certain zoonotic bacterial diseases (A20-A28)": "35",
#     "Chondropathies (M91-M94)": "36",
#     "Chromosomal abnormalities, not elsewhere classified (Q90-Q99)": "37",
#     "Chronic lower respiratory diseases (J40-J47)": "38",
#     "Chronic rheumatic heart diseases (I05-I09)": "39",
#     "Cleft lip and cleft palate (Q35-Q37)": "40",
#     "Coagulation defects, purpura and other hemorrhagic conditions (D65-D69)": "41",
#     "Complications of labor and delivery (O60-O77)": "42",
#     "Complications of surgical and medical care, not elsewhere classified (T80-T88)": "43",
#     "Complications predominantly related to the puerperium (O85-O92)": "44",
#     "Conditions involving the integument and temperature regulation of newborn (P80-P83)": "45",
#     "Congenital malformations and deformations of the musculoskeletal system (Q65-Q79)": "46",
#     "Congenital malformations of eye, ear, face and neck (Q10-Q18)": "47",
#     "Congenital malformations of genital organs (Q50-Q56)": "48",
#     "Congenital malformations of the circulatory system (Q20-Q28)": "49",
#     "Congenital malformations of the nervous system (Q00-Q07)": "50",
#     "Congenital malformations of the respiratory system (Q30-Q34)": "51",
#     "Congenital malformations of the urinary system (Q60-Q64)": "52",
#     "Contact with heat and hot substances (X10-X19)": "53",
#     "Deforming dorsopathies (M40-M43)": "54",
#     "Demyelinating diseases of the central nervous system (G35-G37)": "55",
#     "Dentofacial anomalies [including malocclusion] and other disorders of jaw (M26-M27)": "56",
#     "Dermatitis and eczema (L20-L30)": "57",
#     "Diabetes mellitus (E08-E13)": "58",
#     "Digestive system disorders of newborn (P76-P78)": "59",
#     "Diseases of appendix (K35-K38)": "60",
#     "Diseases of arteries, arterioles and capillaries (I70-I79)": "61",
#     "Diseases of esophagus, stomach and duodenum (K20-K31)": "62",
#     "Diseases of external ear (H60-H62)": "63",
#     "Diseases of inner ear (H80-H83)": "64",
#     "Diseases of liver (K70-K77)": "65",
#     "Diseases of male genital organs (N40-N53)": "66",
#     "Diseases of middle ear and mastoid (H65-H75)": "67",
#     "Diseases of myoneural junction and muscle (G70-G73)": "68",
#     "Diseases of oral cavity and salivary glands (K00-K14)": "69",
#     "Diseases of peritoneum and retroperitoneum (K65-K68)": "70",
#     "Diseases of veins, lymphatic vessels and lymph nodes, not elsewhere classified (I80-I89)": "71",
#     "Disorders of adult personality and behavior (F60-F69)": "72",
#     "Disorders of bone density and structure (M80-M85)": "73",
#     "Disorders of breast (N60-N65)": "74",
#     "Disorders of choroid and retina (H30-H36)": "75",
#     "Disorders of conjunctiva (H10-H11)": "76",
#     "Disorders of eyelid, lacrimal system and orbit (H00-H05)": "77",
#     "Disorders of gallbladder, biliary tract and pancreas (K80-K87)": "78",
#     "Disorders of lens (H25-H28)": "79",
#     "Disorders of muscles (M60-M63)": "80",
#     "Disorders of newborn related to length of gestation and fetal growth (P05-P08)": "81",
#     "Disorders of ocular muscles, binocular movement, accommodation and refraction (H49-H52)": "82",
#     "Disorders of optic nerve and visual pathways (H46-H47)": "83",
#     "Disorders of other endocrine glands (E20-E35)": "84",
#     "Disorders of sclera, cornea, iris and ciliary body (H15-H22)": "85",
#     "Disorders of skin appendages (L60-L75)": "86",
#     "Disorders of synovium and tendon (M65-M67)": "87",
#     "Disorders of thyroid gland (E00-E07)": "88",
#     "Disorders of vitreous body and globe (H43-H44)": "89",
#     "Edema, proteinuria and hypertensive disorders in pregnancy, childbirth and the puerperium (O10-O16)": "90",
#     "Effects of foreign body entering through natural orifice (T15-T19)": "91",
#     "Encounters for other specific health care (Z40-Z53)": "92",
#     "Episodic and paroxysmal disorders (G40-G47)": "93",
#     "Estrogen receptor status": "94",
#     "Event of undetermined intent (Y21-Y33)": "95",
#     "Exposure to animate mechanical forces (W50-W64)": "96",
#     "Exposure to electric current, radiation and extreme ambient air temperature and pressure (W85-W99)": "97",
#     "Exposure to forces of nature (X30-X39)": "98",
#     "Exposure to inanimate mechanical forces (W20-W49)": "99",
#     "Exposure to smoke, fire and flames (X00-X08)": "100",
#     "Extrapyramidal and movement disorders (G20-G26)": "101",
#     "Frostbite (T33-T34)": "102",
#     "General symptoms and signs (R50-R69)": "103",
#     "Genetic carrier and genetic susceptibility to disease (Z14-Z15)": "104",
#     "Glaucoma (H40-H42)": "105",
#     "Glomerular diseases (N00-N08)": "106",
#     "Helminthiases (B65-B83)": "107",
#     "Hemolytic anemias (D55-D59)": "108",
#     "Hemorrhagic and hematological disorders of newborn (P50-P61)": "109",
#     "Hernia (K40-K46)": "110",
#     "Hormone sensitivity malignancy status": "111",
#     "Hypertensive diseases (I10-I16)": "112",
#     "In situ neoplasms (D00-D09)": "113",
#     "Infections of the skin and subcutaneous tissue (L00-L08)": "114",
#     "Infections specific to the perinatal period (P35-P39)": "115",
#     "Infections with a predominantly sexual mode of transmission (A50-A64)": "116",
#     "Infectious arthropathies (M00-M02)": "117",
#     "Inflammatory diseases of female pelvic organs (N70-N77)": "118",
#     "Inflammatory diseases of the central nervous system (G00-G09)": "119",
#     "Inflammatory polyarthropathies (M05-M14)": "120",
#     "Influenza and pneumonia (J09-J18)": "121",
#     "Injuries to the abdomen, lower back, lumbar spine, pelvis and external genitals (S30-S39)": "122",
#     "Injuries to the ankle and foot (S90-S99)": "123",
#     "Injuries to the elbow and forearm (S50-S59)": "124",
#     "Injuries to the head (S00-S09)": "125",
#     "Injuries to the hip and thigh (S70-S79)": "126",
#     "Injuries to the knee and lower leg (S80-S89)": "127",
#     "Injuries to the neck (S10-S19)": "128",
#     "Injuries to the shoulder and upper arm (S40-S49)": "129",
#     "Injuries to the thorax (S20-S29)": "130",
#     "Injuries to the wrist, hand and fingers (S60-S69)": "131",
#     "Injury of unspecified body region": "132",
#     "Intentional self-harm (X71-X83)": "133",
#     "Intestinal infectious diseases (A00-A09)": "134",
#     "Intraoperative and postprocedural complications and disorders of ear and mastoid process, not elsewhere classified": "135",
#     "Intraoperative and postprocedural complications and disorders of eye and adnexa, not elsewhere classified": "136",
#     "Intraoperative and postprocedural complications and disorders of genitourinary system, not elsewhere classified": "137",
#     "Intraoperative and postprocedural complications and disorders of musculoskeletal system, not elsewhere classified": "138",
#     "Intraoperative and postprocedural complications and disorders of respiratory system, not elsewhere classified": "139",
#     "Intraoperative and postprocedural complications of skin and subcutaneous tissue": "140",
#     "Intraoperative and postprocedural complications of the spleen": "141",
#     "Intraoperative complications of endocrine system": "142",
#     "Ischemic heart diseases (I20-I25)": "143",
#     "Legal intervention, operations of war, military operations, and terrorism (Y35-Y38)": "144",
#     "Lung diseases due to external agents (J60-J70)": "145",
#     "Malignant neoplasm of breast": "146",
#     "Malignant neoplasms of bone and articular cartilage (C40-C41)": "147",
#     "Malignant neoplasms of digestive organs (C15-C26)": "148",
#     "Malignant neoplasms of eye, brain and other parts of central nervous system (C69-C72)": "149",
#     "Malignant neoplasms of female genital organs (C51-C58)": "150",
#     "Malignant neoplasms of ill-defined, other secondary and unspecified sites (C76-C80)": "151",
#     "Malignant neoplasms of lip, oral cavity and pharynx (C00-C14)": "152",
#     "Malignant neoplasms of lymphoid, hematopoietic and related tissue (C81-C96)": "153",
#     "Malignant neoplasms of male genital organs (C60-C63)": "154",
#     "Malignant neoplasms of mesothelial and soft tissue (C45-C49)": "155",
#     "Malignant neoplasms of respiratory and intrathoracic organs (C30-C39)": "156",
#     "Malignant neoplasms of thyroid and other endocrine glands (C73-C75)": "157",
#     "Malignant neoplasms of urinary tract (C64-C68)": "158",
#     "Malignant neuroendocrine tumors": "159",
#     "Malnutrition (E40-E46)": "160",
#     "Maternal care related to the fetus and amniotic cavity and possible delivery problems (O30-O48)": "161",
#     "Medical devices associated with adverse incidents in diagnostic and therapeutic use (Y70-Y82)": "162",
#     "Melanoma and other malignant neoplasms of skin (C43-C44)": "163",
#     "Mental and behavioral disorders due to psychoactive substance use (F10-F19)": "164",
#     "Mental disorders due to known physiological conditions (F01-F09)": "165",
#     "Metabolic disorders (E70-E88)": "166",
#     "Misadventures to patients during surgical and medical care (Y62-Y69)": "167",
#     "Mood [affective] disorders (F30-F39)": "168",
#     "Motorcycle rider injured in transport accident (V20-V29)": "169",
#     "Mycoses (B35-B49)": "170",
#     "Neoplasms of uncertain behavior, polycythemia vera and myelodysplastic syndromes (D37-D48)": "171",
#     "Neoplasms of unspecified behavior": "172",
#     "Nerve, nerve root and plexus disorders (G50-G59)": "173",
#     "Newborn affected by maternal factors and by complications of pregnancy, labor, and delivery (P00-P04)": "174",
#     "Noninfective enteritis and colitis (K50-K52)": "175",
#     "Noninflammatory disorders of female genital tract (N80-N98)": "176",
#     "Nutritional anemias (D50-D53)": "177",
#     "Occupant of heavy transport vehicle injured in transport accident (V60-V69)": "178",
#     "Occupant of pick-up truck or van injured in transport accident (V50-V59)": "179",
#     "Occupant of three-wheeled motor vehicle injured in transport accident (V30-V39)": "180",
#     "Osteoarthritis (M15-M19)": "181",
#     "Other acquired deformities of musculoskeletal system and connective tissue": "182",
#     "Other acute lower respiratory infections (J20-J22)": "183",
#     "Other and unspecified disorders of the circulatory system (I95-I99)": "184",
#     "Other and unspecified effects of external causes (T66-T78)": "185",
#     "Other and unspecified infectious diseases": "186",
#     "Other and unspecified transport accidents (V98-V99)": "187",
#     "Other bacterial diseases (A30-A49)": "188",
#     "Other congenital malformations (Q80-Q89)": "189",
#     "Other congenital malformations of the digestive system (Q38-Q45)": "190",
#     "Other degenerative diseases of the nervous system (G30-G32)": "191",
#     "Other diseases caused by chlamydiae (A70-A74)": "192",
#     "Other diseases of intestines (K55-K64)": "193",
#     "Other diseases of the digestive system (K90-K95)": "194",
#     "Other diseases of the pleura (J90-J94)": "195",
#     "Other diseases of the respiratory system (J96-J99)": "196",
#     "Other diseases of the urinary system (N30-N39)": "197",
#     "Other diseases of upper respiratory tract (J30-J39)": "198",
#     "Other disorders of blood and blood-forming organs (D70-D77)": "199",
#     "Other disorders of ear (H90-H94)": "200",
#     "Other disorders of eye and adnexa (H55-H57)": "201",
#     "Other disorders of glucose regulation and pancreatic internal secretion (E15-E16)": "202",
#     "Other disorders of kidney and ureter (N25-N29)": "203",
#     "Other disorders of the nervous system (G89-G99)": "204",
#     "Other disorders of the skin and subcutaneous tissue (L80-L99)": "205",
#     "Other disorders originating in the perinatal period (P90-P96)": "206",
#     "Other dorsopathies (M50-M54)": "207",
#     "Other forms of heart disease (I30-I52)": "208",
#     "Other human herpesviruses": "209",
#     "Other joint disorders (M20-M25)": "210",
#     "Other land transport accidents (V80-V89)": "211",
#     "Other maternal disorders predominantly related to pregnancy (O20-O29)": "212",
#     "Other nutritional deficiencies (E50-E64)": "213",
#     "Other obstetric conditions, not elsewhere classified (O94-O9A)": "214",
#     "Other osteopathies (M86-M90)": "215",
#     "Other respiratory diseases principally affecting the interstitium (J80-J84)": "216",
#     "Other soft tissue disorders (M70-M79)": "217",
#     "Other spirochetal diseases (A65-A69)": "218",
#     "Other viral diseases (B25-B34)": "219",
#     "Overexertion and strenuous or repetitive movements": "220",
#     "Overweight, obesity and other hyperalimentation (E65-E68)": "221",
#     "Papulosquamous disorders (L40-L45)": "222",
#     "Pedal cycle rider injured in transport accident (V10-V19)": "223",
#     "Pedestrian injured in transport accident (V00-V09)": "224",
#     "Pediculosis, acariasis and other infestations (B85-B89)": "225",
#     "Periprosthetic fracture around internal prosthetic joint": "226",
#     "Persons encountering health services for examinations (Z00-Z13)": "227",
#     "Persons encountering health services in circumstances related to reproduction (Z30-Z39)": "228",
#     "Persons encountering health services in other circumstances (Z69-Z76)": "229",
#     "Persons with potential health hazards related to communicable diseases (Z20-Z29)": "230",
#     "Persons with potential health hazards related to family and personal history and certain conditions influencing health status (Z77-Z99)": "231",
#     "Persons with potential health hazards related to socioeconomic and psychosocial circumstances (Z55-Z65)": "232",
#     "Pervasive and specific developmental disorders (F80-F89)": "233",
#     "Poisoning by, adverse effects of and underdosing of drugs, medicaments and biological substances (T36-T50)": "234",
#     "Polyneuropathies and other disorders of the peripheral nervous system (G60-G65)": "235",
#     "Postprocedural endocrine and metabolic complications and disorders, not elsewhere classified": "236",
#     "Pregnancy with abortive outcome (O00-O08)": "237",
#     "Protozoal diseases (B50-B64)": "238",
#     "Pulmonary heart disease and diseases of pulmonary circulation (I26-I28)": "239",
#     "Radiation-related disorders of the skin and subcutaneous tissue (L55-L59)": "240",
#     "Renal tubulo-interstitial diseases (N10-N16)": "241",
#     "Resistance to antimicrobial drugs": "242",
#     "Respiratory and cardiovascular disorders specific to the perinatal period (P19-P29)": "243",
#     "Retained foreign body fragments": "244",
#     "Rickettsioses (A75-A79)": "245",
#     "Schizophrenia, schizotypal, delusional, and other non-mood psychotic disorders (F20-F29)": "246",
#     "Secondary neuroendocrine tumors": "247",
#     "Sequelae of infectious and parasitic diseases (B90-B94)": "248",
#     "Slipping, tripping, stumbling and falls (W00-W19)": "249",
#     "Spondylopathies (M45-M49)": "250",
#     "Supervision of high risk pregnancy": "251",
#     "Supplementary factors related to causes of morbidity classified elsewhere (Y90-Y99)": "252",
#     "Suppurative and necrotic conditions of the lower respiratory tract (J85-J86)": "253",
#     "Surgical and other medical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure (Y83-Y84)": "254",
#     "Symptoms and signs involving cognition, perception, emotional state and behavior (R40-R46)": "255",
#     "Symptoms and signs involving speech and voice (R47-R49)": "256",
#     "Symptoms and signs involving the circulatory and respiratory systems (R00-R09)": "257",
#     "Symptoms and signs involving the digestive system and abdomen (R10-R19)": "258",
#     "Symptoms and signs involving the genitourinary system (R30-R39)": "259",
#     "Symptoms and signs involving the nervous and musculoskeletal systems (R25-R29)": "260",
#     "Symptoms and signs involving the skin and subcutaneous tissue (R20-R23)": "261",
#     "Systemic atrophies primarily affecting the central nervous system (G10-G14)": "262",
#     "Systemic connective tissue disorders (M30-M36)": "263",
#     "Toxic effects of substances chiefly nonmedicinal as to source (T51-T65)": "264",
#     "Transitory endocrine and metabolic disorders specific to newborn (P70-P74)": "265",
#     "Tuberculosis (A15-A19)": "266",
#     "Unspecified multiple injuries": "267",
#     "Urolithiasis (N20-N23)": "268",
#     "Urticaria and erythema (L49-L54)": "269",
#     "Viral and prion infections of the central nervous system (A80-A89)": "270",
#     "Viral hepatitis (B15-B19)": "271",
#     "Viral infections characterized by skin and mucous membrane lesions (B00-B09)": "272",
#     "Visual disturbances and blindness (H53-H54)": "273",
#     "Water transport accidents (V90-V94)": "274"
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "mpnet",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "problem_type": "single_label_classification",
#   "relative_attention_num_buckets": 32,
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "vocab_size": 30527
# }
#
# loading weights file /content/drive/MyDrive/other/icd_stclassification/pytorch_model.bin
# All model checkpoint weights were used when initializing MPNetForSequenceClassification.
#
# All the weights of MPNetForSequenceClassification were initialized from the model checkpoint at /content/drive/MyDrive/other/icd_stclassification.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use MPNetForSequenceClassification for predictions without further training.
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json

# %%
# %env TOKEN_HF=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
# Out:
# env: TOKEN_HF=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

# %%
import os
model_.push_to_hub("setfit-ICD10-L3",use_auth_token=os.getenv("TOKEN_HF"))
tokenizer_.push_to_hub("setfit-ICD10-L3",use_auth_token=os.getenv("TOKEN_HF"))
# Out:
# Configuration saved in /tmp/tmpqstr17vq/config.json
# Model weights saved in /tmp/tmpqstr17vq/pytorch_model.bin
# Uploading the following files to rjac/setfit-ICD10-L3: config.json,pytorch_model.bin
# tokenizer config file saved in /tmp/tmphkr23a2p/tokenizer_config.json
# Special tokens file saved in /tmp/tmphkr23a2p/special_tokens_map.json
# Uploading the following files to rjac/setfit-ICD10-L3: tokenizer.json,special_tokens_map.json,tokenizer_config.json,vocab.txt
# CommitInfo(commit_url='https://huggingface.co/rjac/setfit-ICD10-L3/commit/42f1d61d186ee71899114a89e9f3b8f37f89a4a4', commit_message='Upload tokenizer', commit_description='', oid='42f1d61d186ee71899114a89e9f3b8f37f89a4a4', pr_url=None, pr_revision=None, pr_num=None)

# %%
from transformers import pipeline

# %%
pipe = pipeline("text-classification",model=model_,tokenizer=tokenizer_)

# %%
pipe(["high-grade gliomas or medulloblastomas"])
# Out:
# Disabling tokenizer parallelism, we're using DataLoader multithreading already
# [{'label': 'Malignant neoplasms of lymphoid, hematopoietic and related tissue (C81-C96)',
#   'score': 0.372622549533844}]

# %%
validation_dataset
# Out:
# Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 14296
# })

# %%
validation_ = trainer.predict(validation_dataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 14296
#   Batch size = 1024

# %%
y_hat = np.argmax(validation_.predictions,axis=1)

# %%
y_true = validation_dataset["labels"]

# %%
y_hat_ = [id2label.get(str(i)) for i in y_hat]

# %%
y_true_ = [id2label.get(str(i)) for i in y_true]

# %%
print(metrics.classification_report(y_true_,y_hat_,zero_division=False))
# Out:
#                                                                                                                                                                                           precision    recall  f1-score   support
#
#                                                                                             Abnormal findings on diagnostic imaging and in function studies, without diagnosis (R90-R94)       1.00      0.83      0.91         6
#                                                                                                                   Abnormal findings on examination of blood, without diagnosis (R70-R79)       0.88      0.58      0.70        12
#                                                                               Abnormal findings on examination of other body fluids, substances and tissues, without diagnosis (R83-R89)       0.95      1.00      0.97        19
#                                                                                                                   Abnormal findings on examination of urine, without diagnosis (R80-R82)       0.67      0.80      0.73         5
#                                                                                                                                                                   Abnormal tumor markers       0.00      0.00      0.00         1
#                                                                                                                                 Accidental exposure to other specified factors (X52-X58)       1.00      1.00      1.00         1
#                                                                                                                               Accidental non-transport drowning and submersion (W65-W74)       1.00      1.00      1.00         1
#                                                                                                                                Acute kidney failure and chronic kidney disease (N17-N19)       1.00      0.67      0.80         3
#                                                                                                                                                          Acute rheumatic fever (I00-I02)       0.00      0.00      0.00         1
